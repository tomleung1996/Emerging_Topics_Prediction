# %% [markdown]
# ### 循环神经网络模型模型：Encoder-Decoder with LSTM cell
#
# 新思路：将样本ID经过embedding之后，作为init_state输入到RNN中

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from utils import *
import tensorflow.keras as keras
from tensorflow.keras import regularizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import OneHotEncoder

random.seed(42)

# %% [markdown]
# 读取数据

# %%
# (term_num, time_steps, feature_num)

gene_arr_path = r'../output/gene_editing/result.array'
transplant_arr_path = r'../output/transplant/old_school.array'

gene_arr = pickle.load(open(gene_arr_path, mode='rb'))
transplant_arr = pickle.load(open(transplant_arr_path, mode='rb'))

print('Shape of the gene_editing array:',gene_arr.shape)
print('Shape of the transplant array:',transplant_arr.shape)
# Out:
# Shape of the gene_editing array: (2643, 17, 11)
# Shape of the transplant array: (5141, 17, 11)

# %%
i = 34
print('Document frequency:', transplant_arr[i, :, 0])
print('Emerging score:', transplant_arr[i, :, -2])
print('Total DF:', np.sum(transplant_arr[i, :, 0]))
plt.plot(transplant_arr[i, :, -2])
plt.show()
# Out:
# Document frequency: [0. 0. 0. 0. 0. 1. 2. 0. 1. 3. 2. 2. 0. 0. 2. 0. 0.]
# Emerging score: [0.         0.         0.         0.         0.         0.69314718
#  1.64791843 0.         0.69314718 2.77258872 0.82395922 1.09861229
#  0.         0.         1.09861229 0.         0.        ]
# Total DF: 13.0

# %% [markdown]
# ### 截断数据
# 因2019年两个数据集的EmergingScore大部分都为0，而2018年及之前的情况要好很多，故抛弃2019年数据

# %%
gene_arr = gene_arr[:, :-1, :]
transplant_arr = transplant_arr[:, :-1, :]

print('Shape of the gene_editing array:',gene_arr.shape)
print('Shape of the transplant array:',transplant_arr.shape)
# Out:
# Shape of the gene_editing array: (2643, 16, 11)
# Shape of the transplant array: (5141, 16, 11)

# %% [markdown]
# ### 规范数据并获取训练集和测试集

# %%
scaler, data = scale_data(transplant_arr, 'standard')
# X_train, X_test, y_train, y_test = split_data(data, 11, 0.2)
X_train, X_test, y_train, y_test = split_data_by_time(data, 6, 5, False)
# _, _, _, y_test_origin = split_data_by_time(transplant_arr, 6, 5, False)
print('X_train.shape:', X_train.shape)
print('X_test.shape:', X_test.shape)
print('y_train.shape:', y_train.shape)
print('y_test.shape:', y_test.shape)
# Out:
# X_train.shape: (5141, 6, 11)
# X_test.shape: (5141, 6, 11)
# y_train.shape: (5141, 5)
# y_test.shape: (5141, 5)

# %% [markdown]
# ### 构建模型

# %%
def build_direct_model(lstm_units, dense_units):
    model = keras.models.Sequential()
    model.add(LSTM(lstm_units, activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
    model.add(LSTM(lstm_units, activation='tanh'))
    model.add(Dense(dense_units, activation='relu'))
    model.add(Dense(y_train.shape[1]))
    
    model.compile(loss='mae', optimizer='rmsprop')
    return model

# %%
def build_encoder_decoder_model(lstm_units, dense_units):
    model = keras.models.Sequential()
    model.add(LSTM(lstm_units, activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
    model.add(LSTM(lstm_units, activation='tanh'))
    model.add(RepeatVector(y_train.shape[1]))
    model.add(LSTM(lstm_units, activation='tanh', return_sequences=True))
    model.add(LSTM(lstm_units, activation='tanh', return_sequences=True))
    model.add(TimeDistributed(Dense(dense_units, activation='relu')))
    model.add(TimeDistributed(Dense(1)))
    
    model.compile(loss='mae', optimizer='rmsprop')
    return model

# %%
def build_tf_encoder_decoder_model(input_dims, output_dims, lstm_units):
    # 训练模式
    # encoder，获取其隐藏状态，丢弃其输出
    enc_inputs = Input(shape=(None, input_dims))
    enc = LSTM(lstm_units, return_state=True, dropout=0.2)
    enc_outputs, state_h, state_c = enc(enc_inputs)
    enc_states = [state_h, state_c]
    
    # decoder，输入encoder的隐藏状态和目标序列的往后平移1位的输入，以一个开始标记开始
    dec_inputs = Input(shape=(None, output_dims))
    dec = LSTM(lstm_units, return_sequences=True, return_state=True, dropout=0.2)
    dec_outputs, _, _ = dec(dec_inputs, initial_state=enc_states)
    
    # dense输出
    dec_dense = Dense(output_dims, activation=None)
    dec_outputs = dec_dense(dec_outputs)
    
    model = Model([enc_inputs, dec_inputs], dec_outputs)
    
    # 推断模式，重用了上面的层，下面的模型只需要predict而不需要train
    # encoder很简单，一样的
    enc_model = Model(enc_inputs, enc_states)
    
    # decoder和前面不同的是需要接收自己的隐藏状态（第一次为encoder的隐藏状态），
    # 这里的shape为什么是这样？
    dec_state_input_h = Input(shape=(lstm_units,))
    dec_state_input_c = Input(shape=(lstm_units,))
    dec_states_inputs = [dec_state_input_h, dec_state_input_c]
    dec_outputs, state_h, state_c = dec(dec_inputs, initial_state=dec_states_inputs)
    dec_states = [state_h, state_c]
    dec_outputs = dec_dense(dec_outputs)
    
    dec_model = Model([dec_inputs] + dec_states_inputs,
                     [dec_outputs] + dec_states)
    
    model.compile(optimizer='rmsprop', loss='mae')
    
    return model, enc_model, dec_model

def predict_seq(enc_model, dec_model, input_seq, pred_steps):
    # 先encode序列，获得encoder的隐藏状态
    enc_states = enc_model.predict(input_seq)
    
    # 生成一个形状为(samples, timesteps, output_dims)的占位序列，该序列由开始标记开始
    # 这里我们一步步进行
    # 开始标记的选择也是个问题，暂时用0.0
    target_seq = np.zeros((1, 1, 1))
    target_seq[0, 0, 0] = 0.0
    
    output_seq = []
    for _ in range(pred_steps):
        single_out, h, c = dec_model.predict([target_seq] + enc_states)
        
        output_seq.append(single_out[0, 0, 0])
        
        target_seq = np.zeros((1, 1, 1))
        target_seq[0, 0, 0] = single_out[0, 0, 0]
        
        enc_states = [h, c]
    
    return output_seq

# %%
def build_tf_id_encoder_decoder_model(input_dims, output_dims, id_dims, lstm_units):
    # 训练模式
    # ID接入
    id_inputs = Input(shape=(id_dims,))
#     id_dense = Dense(512, activation='relu')(id_inputs)
    id_dense = Dense(lstm_units, activation='relu')
    id_outputs = id_dense(id_inputs)
    id_outputs = Dropout(0.4)(id_outputs)
    id_states = [id_outputs, id_outputs]
    
    # encoder，获取其隐藏状态，丢弃其输出
    enc_inputs = Input(shape=(None, input_dims))
    enc = LSTM(lstm_units, return_state=True)
    enc_outputs, state_h, state_c = enc(enc_inputs, initial_state=id_states)
    enc_states = [state_h, state_c]
    
    # decoder，输入encoder的隐藏状态和目标序列的往后平移1位的输入，以一个开始标记开始
    dec_inputs = Input(shape=(None, output_dims))
    dec = LSTM(lstm_units, return_sequences=True, return_state=True)
    dec_outputs, _, _ = dec(dec_inputs, initial_state=enc_states)
    
    # dense输出
    dec_dense = Dense(output_dims, activation=None)
    dec_outputs = dec_dense(dec_outputs)
    
    model = Model([enc_inputs, dec_inputs, id_inputs], dec_outputs)
    
    # 推断模式，重用了上面的层，下面的模型只需要predict而不需要train
    # encoder很简单，一样的
    enc_model = Model([enc_inputs, id_inputs], enc_states)
    
    # decoder和前面不同的是需要接收自己的隐藏状态（第一次为encoder的隐藏状态），
    # 这里的shape为什么是这样？
    dec_state_input_h = Input(shape=(lstm_units,))
    dec_state_input_c = Input(shape=(lstm_units,))
    dec_states_inputs = [dec_state_input_h, dec_state_input_c]
    dec_outputs, state_h, state_c = dec(dec_inputs, initial_state=dec_states_inputs)
    dec_states = [state_h, state_c]
    dec_outputs = dec_dense(dec_outputs)
    
    dec_model = Model([dec_inputs] + dec_states_inputs,
                     [dec_outputs] + dec_states)
    
    model.compile(optimizer='rmsprop', loss='mae')
    
    return model, enc_model, dec_model

def predict_seq_with_id(enc_model, dec_model, input_seq, ids, pred_steps):
    # 先encode序列，获得encoder的隐藏状态
    enc_states = enc_model.predict([input_seq.copy(), ids.copy()])
    
    # 生成一个形状为(samples, timesteps, output_dims)的占位序列，该序列由开始标记开始
    # 这里我们一步步进行
    # 开始标记的选择也是个问题，暂时用0.0
    target_seq = np.zeros((1, 1, 1))
    target_seq[0, 0, 0] = 0.0
    
    output_seq = []
    for _ in range(pred_steps):
        single_out, h, c = dec_model.predict([target_seq] + enc_states)
        
        output_seq.append(single_out[0, 0, 0])
        
        target_seq = np.zeros((1, 1, 1))
        target_seq[0, 0, 0] = single_out[0, 0, 0]
        
        enc_states = [h, c]
    
    return output_seq

# %% [markdown]
# 训练

# %%
decoder_in_training = np.roll(y_train, 1, axis=1)
decoder_in_training[:, 0] = 0.0
decoder_in_training = decoder_in_training.reshape(len(decoder_in_training), -1, 1)

decoder_in_validation = np.roll(y_test, 1, axis=1)
decoder_in_validation[:, 0] = 0.0
decoder_in_validation = decoder_in_validation.reshape(len(decoder_in_validation), -1, 1)

ids = np.arange(len(X_train)).reshape(-1, 1)
enc = OneHotEncoder(categories='auto')
ids = enc.fit_transform(ids).toarray()

# %%
model = build_direct_model(256, 256)
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), callbacks=[])
# Out:
# Train on 5141 samples, validate on 5141 samples
# Epoch 1/20
# 5141/5141 [==============================] - 13s 3ms/sample - loss: 0.3216 - val_loss: 0.2437
# Epoch 2/20
# 5141/5141 [==============================] - 7s 1ms/sample - loss: 0.3001 - val_loss: 0.2612
# Epoch 3/20
# 5141/5141 [==============================] - 7s 1ms/sample - loss: 0.2969 - val_loss: 0.2804
# Epoch 4/20
# 5141/5141 [==============================] - 7s 1ms/sample - loss: 0.2950 - val_loss: 0.2564
# Epoch 5/20
# 5141/5141 [==============================] - 7s 1ms/sample - loss: 0.2942 - val_loss: 0.2542
# Epoch 6/20
# 5141/5141 [==============================] - 7s 1ms/sample - loss: 0.2926 - val_loss: 0.2587
# Epoch 7/20
# 5141/5141 [==============================] - 7s 1ms/sample - loss: 0.2922 - val_loss: 0.2480
# Epoch 8/20
# 5141/5141 [==============================] - 8s 2ms/sample - loss: 0.2907 - val_loss: 0.2462
# Epoch 9/20
# 5141/5141 [==============================] - 7s 1ms/sample - loss: 0.2894 - val_loss: 0.2653
# Epoch 10/20
# 5141/5141 [==============================] - 7s 1ms/sample - loss: 0.2886 - val_loss: 0.2465
# Epoch 11/20
# 5141/5141 [==============================] - 7s 1ms/sample - loss: 0.2877 - val_loss: 0.2530
# Epoch 12/20
# 5141/5141 [==============================] - 7s 1ms/sample - loss: 0.2869 - val_loss: 0.2546
# Epoch 13/20
# 5141/5141 [==============================] - 7s 1ms/sample - loss: 0.2855 - val_loss: 0.2456
# Epoch 14/20
# 5141/5141 [==============================] - 8s 2ms/sample - loss: 0.2844 - val_loss: 0.2479
# Epoch 15/20
# 5141/5141 [==============================] - 8s 2ms/sample - loss: 0.2832 - val_loss: 0.2478
# Epoch 16/20
# 5141/5141 [==============================] - 8s 1ms/sample - loss: 0.2821 - val_loss: 0.2458
# Epoch 17/20
# 5141/5141 [==============================] - 8s 2ms/sample - loss: 0.2809 - val_loss: 0.2514
# Epoch 18/20
# 5141/5141 [==============================] - 8s 1ms/sample - loss: 0.2790 - val_loss: 0.2527
# Epoch 19/20
# 5141/5141 [==============================] - 8s 1ms/sample - loss: 0.2777 - val_loss: 0.2504
# Epoch 20/20
# 5141/5141 [==============================] - 8s 1ms/sample - loss: 0.2778 - val_loss: 0.2515

# %%
model = build_encoder_decoder_model(256, 256)
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), callbacks=[])
# Out:
# Train on 5141 samples, validate on 5141 samples
# Epoch 1/100
# 5141/5141 [==============================] - 26s 5ms/sample - loss: 0.5145 - val_loss: 0.4458
# Epoch 2/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4887 - val_loss: 0.4373
# Epoch 3/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4830 - val_loss: 0.4522
# Epoch 4/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4793 - val_loss: 0.4496
# Epoch 5/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4784 - val_loss: 0.4387
# Epoch 6/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4753 - val_loss: 0.4311
# Epoch 7/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4763 - val_loss: 0.4345
# Epoch 8/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4732 - val_loss: 0.4339
# Epoch 9/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4727 - val_loss: 0.4336
# Epoch 10/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4712 - val_loss: 0.4442
# Epoch 11/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4713 - val_loss: 0.4348
# Epoch 12/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4694 - val_loss: 0.4400
# Epoch 13/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4678 - val_loss: 0.4494
# Epoch 14/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4678 - val_loss: 0.4497
# Epoch 15/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4652 - val_loss: 0.4397
# Epoch 16/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4641 - val_loss: 0.4418
# Epoch 17/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4627 - val_loss: 0.4506
# Epoch 18/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4623 - val_loss: 0.4386
# Epoch 19/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4610 - val_loss: 0.4405
# Epoch 20/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4585 - val_loss: 0.4430
# Epoch 21/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4576 - val_loss: 0.4442
# Epoch 22/100
# 5141/5141 [==============================] - 16s 3ms/sample - loss: 0.4546 - val_loss: 0.4403
# Epoch 23/100
# 5141/5141 [==============================] - 16s 3ms/sample - loss: 0.4531 - val_loss: 0.4362
# Epoch 24/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4501 - val_loss: 0.4514
# Epoch 25/100
# 5141/5141 [==============================] - 15s 3ms/sample - loss: 0.4478 - val_loss: 0.4437
# Epoch 26/100
# 5141/5141 [==============================] - 16s 3ms/sample - loss: 0.4455 - val_loss: 0.4438

# %%
model, encoder_model, decoder_model = build_tf_encoder_decoder_model(11, 1, 512)
history = model.fit([X_train, decoder_in_training], y_train, 
                    epochs=50, validation_data=([X_test, decoder_in_validation], y_test), batch_size=16,
                    callbacks=[])
# Out:
# Train on 5141 samples, validate on 5141 samples
# Epoch 1/50
# 5141/5141 [==============================] - 33s 6ms/sample - loss: 0.4971 - val_loss: 0.4796
# Epoch 2/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4833 - val_loss: 0.4677
# Epoch 3/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4795 - val_loss: 0.4744
# Epoch 4/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4760 - val_loss: 0.4663
# Epoch 5/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4731 - val_loss: 0.4770
# Epoch 6/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4714 - val_loss: 0.4667
# Epoch 7/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4684 - val_loss: 0.4606
# Epoch 8/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4670 - val_loss: 0.4645
# Epoch 9/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4662 - val_loss: 0.4570
# Epoch 10/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4643 - val_loss: 0.4576
# Epoch 11/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4629 - val_loss: 0.4583
# Epoch 12/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4626 - val_loss: 0.4564
# Epoch 13/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4610 - val_loss: 0.4610
# Epoch 14/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4605 - val_loss: 0.4635
# Epoch 15/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4593 - val_loss: 0.4645
# Epoch 16/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4577 - val_loss: 0.4593
# Epoch 17/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4571 - val_loss: 0.4619
# Epoch 18/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4536 - val_loss: 0.4620
# Epoch 19/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4539 - val_loss: 0.4665
# Epoch 20/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4523 - val_loss: 0.4699
# Epoch 21/50
# 5141/5141 [==============================] - 29s 6ms/sample - loss: 0.4485 - val_loss: 0.4810
# Epoch 22/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4477 - val_loss: 0.4673
# Epoch 23/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4438 - val_loss: 0.4674
# Epoch 24/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4422 - val_loss: 0.4694
# Epoch 25/50
# 5141/5141 [==============================] - 28s 6ms/sample - loss: 0.4416 - val_loss: 0.4690
# Epoch 26/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4368 - val_loss: 0.4690
# Epoch 27/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4358 - val_loss: 0.4797
# Epoch 28/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4337 - val_loss: 0.4752
# Epoch 29/50
# 5141/5141 [==============================] - 28s 6ms/sample - loss: 0.4296 - val_loss: 0.4831
# Epoch 30/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4270 - val_loss: 0.4778
# Epoch 31/50
# 5141/5141 [==============================] - 27s 5ms/sample - loss: 0.4225 - val_loss: 0.4817
# Epoch 32/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4206 - val_loss: 0.4789
# Epoch 33/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4183 - val_loss: 0.4847
# Epoch 34/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4119 - val_loss: 0.4901
# Epoch 35/50
# 5141/5141 [==============================] - 28s 5ms/sample - loss: 0.4110 - val_loss: 0.4832
# Epoch 36/50
# 5141/5141 [==============================] - 29s 6ms/sample - loss: 0.4070 - val_loss: 0.4853
# Epoch 37/50
# 5141/5141 [==============================] - 31s 6ms/sample - loss: 0.4029 - val_loss: 0.4837
# Epoch 38/50
# 5141/5141 [==============================] - 32s 6ms/sample - loss: 0.3995 - val_loss: 0.4858
# Epoch 39/50
# 5141/5141 [==============================] - 30s 6ms/sample - loss: 0.3982 - val_loss: 0.5014
# Epoch 40/50
# 5141/5141 [==============================] - 30s 6ms/sample - loss: 0.3917 - val_loss: 0.4965
# Epoch 41/50
# 5141/5141 [==============================] - 30s 6ms/sample - loss: 0.3923 - val_loss: 0.5047
# Epoch 42/50
# 5141/5141 [==============================] - 30s 6ms/sample - loss: 0.3820 - val_loss: 0.4956
# Epoch 43/50
# 5141/5141 [==============================] - 30s 6ms/sample - loss: 0.3822 - val_loss: 0.4983
# Epoch 44/50
# 5141/5141 [==============================] - 31s 6ms/sample - loss: 0.3781 - val_loss: 0.5010
# Epoch 45/50
# 5141/5141 [==============================] - 30s 6ms/sample - loss: 0.3738 - val_loss: 0.5061
# Epoch 46/50
# 5141/5141 [==============================] - 30s 6ms/sample - loss: 0.3716 - val_loss: 0.5002
# Epoch 47/50
# 5141/5141 [==============================] - 30s 6ms/sample - loss: 0.3712 - val_loss: 0.5079
# Epoch 48/50
# 5141/5141 [==============================] - 30s 6ms/sample - loss: 0.3675 - val_loss: 0.4977
# Epoch 49/50
# 5141/5141 [==============================] - 30s 6ms/sample - loss: 0.3633 - val_loss: 0.5050
# Epoch 50/50
# 5141/5141 [==============================] - 31s 6ms/sample - loss: 0.3600 - val_loss: 0.5062

# %%
model, encoder_model, decoder_model = build_tf_id_encoder_decoder_model(11, 1, len(ids[0]), 512)
history = model.fit([X_train, decoder_in_training, ids], y_train, 
                    epochs=100, validation_data=([X_test, decoder_in_validation, ids], y_test), batch_size=128,
                    callbacks=[
                        EarlyStopping(monitor='val_loss', patience=20, verbose=0, mode='auto', restore_best_weights=True)
                    ])
# Out:
# Train on 5141 samples, validate on 5141 samples
# Epoch 1/100
# 5141/5141 [==============================] - 16s 3ms/sample - loss: 0.5303 - val_loss: 0.4618
# Epoch 2/100
# 5141/5141 [==============================] - 8s 2ms/sample - loss: 0.4984 - val_loss: 0.4461
# Epoch 3/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.4923 - val_loss: 0.4598
# Epoch 4/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.4905 - val_loss: 0.4431
# Epoch 5/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.4793 - val_loss: 0.4763
# Epoch 6/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.4547 - val_loss: 0.4631
# Epoch 7/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.4329 - val_loss: 0.4880
# Epoch 8/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.4089 - val_loss: 0.4814
# Epoch 9/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.3855 - val_loss: 0.6021
# Epoch 10/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.3657 - val_loss: 0.5260
# Epoch 11/100
# 5141/5141 [==============================] - 10s 2ms/sample - loss: 0.3482 - val_loss: 0.8168
# Epoch 12/100
# 5141/5141 [==============================] - 10s 2ms/sample - loss: 0.3320 - val_loss: 0.5821
# Epoch 13/100
# 5141/5141 [==============================] - 10s 2ms/sample - loss: 0.3242 - val_loss: 0.5728
# Epoch 14/100
# 5141/5141 [==============================] - 10s 2ms/sample - loss: 0.3110 - val_loss: 0.5686
# Epoch 15/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.3028 - val_loss: 0.5508
# Epoch 16/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.2906 - val_loss: 0.5741
# Epoch 17/100
# 5141/5141 [==============================] - 10s 2ms/sample - loss: 0.2822 - val_loss: 0.5868
# Epoch 18/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.2704 - val_loss: 0.5894
# Epoch 19/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.2575 - val_loss: 0.5775
# Epoch 20/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.2459 - val_loss: 0.6857
# Epoch 21/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.2311 - val_loss: 0.5418
# Epoch 22/100
# 5141/5141 [==============================] - 9s 2ms/sample - loss: 0.2159 - val_loss: 0.6842
# Epoch 23/100
# 5141/5141 [==============================] - 10s 2ms/sample - loss: 0.2138 - val_loss: 0.6309
# Epoch 24/100
# 5141/5141 [==============================] - 10s 2ms/sample - loss: 0.2004 - val_loss: 0.6404

# %% [markdown]
# 预测

# %% [markdown]
# from tensorflow.keras.models import load_model
#
# model = load_model(r'C:\Users\Tom Leung\Desktop\best.h5')
# y_pred = model.predict(X_test).reshape(y_test.shape)

# %%
train_pred = model.predict(X_train).reshape(y_train.shape)
y_pred = model.predict(X_test).reshape(y_test.shape)

# %%
# teacher forcing with ID
# y_pred = list()
# for i in range(X_test.shape[0]):
#     y_pred.append(predict_seq_with_id(encoder_model, decoder_model, X_test[i:i+1], ids[i:i+1], pred_steps=3))
# y_pred = np.array(y_pred)

# teacher forcing without ID
y_pred = list()
for i in range(X_test.shape[0]):
    y_pred.append(predict_seq(encoder_model, decoder_model, X_test[i:i+1], pred_steps=5))
y_pred = np.array(y_pred)

# no teacher forcing
# y_pred = model.predict(X_test)
# y_pred = y_pred.reshape(y_test.shape)

# %%
# teacher forcing with ID
# train_pred = list()
# for i in range(X_train.shape[0]):
#     train_pred.append(predict_seq_with_id(encoder_model, decoder_model, X_train[i:i+1], ids[i:i+1], pred_steps=3))
# train_pred = np.array(train_pred)

# teacher forcing without ID
train_pred = list()
for i in range(X_train.shape[0]):
    train_pred.append(predict_seq(encoder_model, decoder_model, X_train[i:i+1], pred_steps=5))
train_pred = np.array(train_pred)

# no teacher forcing
# train_pred = model.predict(X_train)
# train_pred = train_pred.reshape(y_train.shape)

# %%
rand_ids = random.sample(range(len(y_train)), 10)
print(rand_ids)
print(np.std(transplant_arr[rand_ids, :, -2], axis=1))

plt.figure(figsize=(12,8))
for i in range(10):
    plt.subplot(5,2,i+1)
    plt.plot(np.concatenate((X_train[rand_ids[i], :, -2], y_train[rand_ids[i]].reshape(-1)), axis=None), label='actual', zorder=1)
    plt.plot(np.concatenate((X_train[rand_ids[i], :, -2], train_pred[rand_ids[i]].reshape(-1)), axis=None), label='predict', zorder=0)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [2020, 4598, 4415, 2152, 4788, 3509, 4780, 3271, 2965, 1796]
# [0.35505777 0.40245885 1.15371641 0.30014153 0.30014153 0.73771949
#  0.3337226  1.17529001 1.24728914 0.3337226 ]

# %%
rand_ids = random.sample(range(len(y_test)), 10)
print(rand_ids)

plt.figure(figsize=(12,8))
for i in range(10):
    plt.subplot(5,2,i+1)
    plt.plot(np.concatenate((X_test[rand_ids[i], :, -2], y_test[rand_ids[i]].reshape(-1)), axis=None), label='actual', zorder=1)
    plt.plot(np.concatenate((X_test[rand_ids[i], :, -2], y_pred[rand_ids[i]].reshape(-1)), axis=None), label='predict', zorder=0)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [938, 4398, 2185, 2786, 913, 2404, 3561, 1295, 3716, 26]

# %%
rand_ids = random.sample(range(len(y_test)), 10)
print(rand_ids)

plt.figure(figsize=(12,8))
for i in range(10):
    plt.subplot(5,2,i+1)
    if i % 2 == 1:
        plt.plot(np.concatenate((X_test[rand_ids[i], :, -2], y_test[rand_ids[i]].reshape(-1)), axis=None), label='actual', zorder=1)
        plt.plot(np.concatenate((X_test[rand_ids[i], :, -2], y_pred[rand_ids[i]].reshape(-1)), axis=None), label='predict', zorder=0)
    else:
        plt.plot(np.concatenate((X_train[rand_ids[i+1], :, -2], y_train[rand_ids[i+1]].reshape(-1)), axis=None), label='actual', zorder=1)
        plt.plot(np.concatenate((X_train[rand_ids[i+1], :, -2], train_pred[rand_ids[i+1]].reshape(-1)), axis=None), label='predict', zorder=0)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [4363, 1030, 1051, 3893, 4503, 1352, 2171, 4322, 4969, 3466]

# %%
metrics = ['mae', 'ndcg']

for m in metrics:
    overall, annual = eval_model(m, y_test, y_pred.reshape(5141, -1), scaler)
    print('{}:'.format(m.upper()), overall)
    print('{}MAE:'.format(m.upper()),annual)
    plt.plot(annual)
    plt.show()
# Out:
# MAE: 0.5684264287161328
# MAEMAE: [0.58839838 0.57914824 0.53700615 0.56040624 0.57717314]
# NDCG: 0.38826455082885625
# NDCGMAE: [0.003884511785071105, 0.008560690132991823, 0.010428024160098099, 0.08933433043142702, 0.01056091614688008]

# %%
_y_true, _y_pred = eval_model('classification', y_test, y_pred, scaler)

# %%
from sklearn.metrics import classification_report
print(classification_report(_y_true.reshape(-1), _y_pred.reshape(-1)))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.66      0.81      0.73     14768
#          2.0       0.30      0.17      0.22      6860
#          3.0       0.26      0.26      0.26      2600
#          4.0       0.39      0.34      0.36      1477
#
#     accuracy                           0.56     25705
#    macro avg       0.40      0.39      0.39     25705
# weighted avg       0.51      0.56      0.52     25705
