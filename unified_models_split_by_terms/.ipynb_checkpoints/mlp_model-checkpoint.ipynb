# %% [markdown]
# ### 前馈神经网络模型
# 两种方式，一种是循环预测，一种是直接出N年
#
# 0.752 gene MAE
#
# 0.775 transplant MAE

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from utils import *
import tensorflow.keras as keras
from tensorflow.keras.layers import *
from tensorflow.keras.models import *

random.seed(42)

# %% [markdown]
# 读取数据

# %%
# (term_num, time_steps, feature_num)

gene_arr_path = r'../output/gene_editing/es_with_decay.array'
transplant_arr_path = r'../output/transplant/es_with_decay.array'

gene_arr = pickle.load(open(gene_arr_path, mode='rb'))
transplant_arr = pickle.load(open(transplant_arr_path, mode='rb'))

print('Shape of the gene_editing array:',gene_arr.shape)
print('Shape of the transplant array:',transplant_arr.shape)
# Out:
# Shape of the gene_editing array: (2643, 17, 10)
# Shape of the transplant array: (5141, 17, 10)

# %% [markdown]
# ### 截断数据
# 因2019年两个数据集的EmergingScore大部分都为0，而2018年及之前的情况要好很多，故抛弃2019年数据

# %%
gene_arr = gene_arr[:, :-1, :]
transplant_arr = transplant_arr[:, :-1, :]

print('Shape of the gene_editing array:',gene_arr.shape)
print('Shape of the transplant array:',transplant_arr.shape)
# Out:
# Shape of the gene_editing array: (2643, 16, 10)
# Shape of the transplant array: (5141, 16, 10)

# %% [markdown]
# ### 规范数据并获取训练集和测试集
# 这里的训练集、测试集和序列模型的不同，是滑动窗口
#
# 为了保证可比性，使用位置号来标明原来的序列
#
# 因为不是序列模型，所以需要展平多变量序列，也可以使用多个神经网络对每一维进行处理
#
# 此外，因为是多变量序列，所以模型要预测所有的变量，不然没法循环输入
#
# https://machinelearningmastery.com/how-to-develop-multilayer-perceptron-models-for-time-series-forecasting/

# %%
def to_supervised(data, n_inputs, ids_train, ids_test):
    train_data = data[ids_train]
    test_data = data[ids_test]
    
    X_train = list()
    X_test = list()
    y_train = list()
    y_test = list()
    
    for train in train_data:
        for i in range(len(train_data[0]) - n_inputs):
            X_train.append(train[i:i+n_inputs].flatten())
            y_train.append(train[i+n_inputs].flatten())
    
    for test in test_data:
        for i in range(len(test_data[0]) - n_inputs):
            X_test.append(test[i:i+n_inputs].flatten())
            y_test.append(test[i+n_inputs].flatten())
    
    return np.array(X_train), np.array(X_test), np.array(y_train), np.array(y_test)

# %%
scaler, data = scale_data(gene_arr, 'standard')
# scaler, data = scale_data(transplant_arr, 'standard')
X_train, X_test, y_train, y_test, ids_train, ids_test = split_data_with_index(data, n_input=11, ratio=0.2)

# 如果不是循环预测则不需要执行下面这一行
X_train, X_test, y_train, y_test = to_supervised(data, 11, ids_train, ids_test)

# %%
y_train.shape
# Out:
# (10570, 10)

# %%
X_train.shape
# Out:
# (20560, 110)

# %% [markdown]
# ### 构建模型

# %%
def build_recursive_dnn_model():
    model = keras.models.Sequential()
#     model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(y_train.shape[1]))
    model.compile(loss='mae', optimizer='rmsprop')
    return model

def build_direct_dnn_model():
    model = keras.models.Sequential()
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(y_train.shape[1]))
    model.compile(loss='mae', optimizer='rmsprop')
    return model

def build_parallel_dnn_model(n_inputs, n_vars):
    var = []
    denses = []
    
    for i in range(n_vars):
        v = Input(shape=(n_inputs))
        d = Dense(256, activation='relu')(v)
        var.append(v)
        denses.append(d)
    
    merge = concatenate(denses)
    d_2 = Dense(128)(merge)
    output = Dense(5)(d_2)
    
    model = Model(inputs=var, outputs=output)
    model.compile(loss='mae', optimizer='rmsprop')
    
    return model

def build_parallel_X(data):
    Xs = []
    for i in range(data.shape[2]):
        Xs.append(data[:, :, i])
    return Xs

# %% [markdown]
# 训练

# %%
model = build_recursive_dnn_model()
history = model.fit(X_train, y_train, epochs=20, batch_size=16, verbose=1, validation_data=(X_test, y_test))
# Out:
# Train on 10570 samples, validate on 2645 samples
# Epoch 1/20
# 10570/10570 [==============================] - 32s 3ms/sample - loss: 0.2728 - val_loss: 0.2472
# Epoch 2/20
# 10570/10570 [==============================] - 2s 157us/sample - loss: 0.2531 - val_loss: 0.2440
# Epoch 3/20
# 10570/10570 [==============================] - 2s 159us/sample - loss: 0.2496 - val_loss: 0.2453
# Epoch 4/20
# 10570/10570 [==============================] - 2s 162us/sample - loss: 0.2441 - val_loss: 0.2557
# Epoch 5/20
# 10570/10570 [==============================] - 2s 188us/sample - loss: 0.2439 - val_loss: 0.2439
# Epoch 6/20
# 10570/10570 [==============================] - 2s 201us/sample - loss: 0.2404 - val_loss: 0.2401
# Epoch 7/20
# 10570/10570 [==============================] - 2s 197us/sample - loss: 0.2387 - val_loss: 0.2365
# Epoch 8/20
# 10570/10570 [==============================] - 2s 198us/sample - loss: 0.2414 - val_loss: 0.2449
# Epoch 9/20
# 10570/10570 [==============================] - 2s 191us/sample - loss: 0.2321 - val_loss: 0.2396
# Epoch 10/20
# 10570/10570 [==============================] - 2s 189us/sample - loss: 0.2375 - val_loss: 0.2396
# Epoch 11/20
# 10570/10570 [==============================] - 2s 194us/sample - loss: 0.2321 - val_loss: 0.2385
# Epoch 12/20
# 10570/10570 [==============================] - 2s 195us/sample - loss: 0.2287 - val_loss: 0.2433
# Epoch 13/20
# 10570/10570 [==============================] - 2s 191us/sample - loss: 0.2271 - val_loss: 0.2414
# Epoch 14/20
# 10570/10570 [==============================] - 2s 189us/sample - loss: 0.2265 - val_loss: 0.2412
# Epoch 15/20
# 10570/10570 [==============================] - 2s 189us/sample - loss: 0.2218 - val_loss: 0.2409
# Epoch 16/20
# 10570/10570 [==============================] - 2s 188us/sample - loss: 0.2186 - val_loss: 0.2412
# Epoch 17/20
# 10570/10570 [==============================] - 2s 189us/sample - loss: 0.2188 - val_loss: 0.2421
# Epoch 18/20
# 10570/10570 [==============================] - 2s 190us/sample - loss: 0.2158 - val_loss: 0.2427
# Epoch 19/20
# 10570/10570 [==============================] - 2s 187us/sample - loss: 0.2188 - val_loss: 0.2415
# Epoch 20/20
# 10570/10570 [==============================] - 2s 192us/sample - loss: 0.2144 - val_loss: 0.2418

# %%
Xs_train = build_parallel_X(X_train)
Xs_test = build_parallel_X(X_test)
model = build_parallel_dnn_model(11, 11)
history = model.fit(Xs_train, y_train, epochs=100, batch_size=16, verbose=1, validation_data=(Xs_test, y_test), 
                   callbacks=[])
# Out:
# Train on 4112 samples, validate on 1029 samples
# Epoch 1/100
# 4112/4112 [==============================] - 3s 691us/sample - loss: 0.6297 - val_loss: 0.5345
# Epoch 2/100
# 4112/4112 [==============================] - 1s 337us/sample - loss: 0.5466 - val_loss: 0.5010
# Epoch 3/100
# 4112/4112 [==============================] - 1s 341us/sample - loss: 0.5282 - val_loss: 0.4937
# Epoch 4/100
# 4112/4112 [==============================] - 1s 340us/sample - loss: 0.5207 - val_loss: 0.4934
# Epoch 5/100
# 4112/4112 [==============================] - 1s 338us/sample - loss: 0.5145 - val_loss: 0.4907
# Epoch 6/100
# 4112/4112 [==============================] - 1s 343us/sample - loss: 0.5120 - val_loss: 0.4947
# Epoch 7/100
# 4112/4112 [==============================] - 1s 345us/sample - loss: 0.5102 - val_loss: 0.4944
# Epoch 8/100
# 4112/4112 [==============================] - 1s 349us/sample - loss: 0.5069 - val_loss: 0.5070
# Epoch 9/100
# 4112/4112 [==============================] - 1s 354us/sample - loss: 0.5071 - val_loss: 0.4932
# Epoch 10/100
# 4112/4112 [==============================] - 2s 380us/sample - loss: 0.5023 - val_loss: 0.4929
# Epoch 11/100
# 4112/4112 [==============================] - 2s 389us/sample - loss: 0.5035 - val_loss: 0.4926
# Epoch 12/100
# 4112/4112 [==============================] - 2s 419us/sample - loss: 0.4985 - val_loss: 0.4950
# Epoch 13/100
# 4112/4112 [==============================] - 2s 436us/sample - loss: 0.4947 - val_loss: 0.4938
# Epoch 14/100
# 4112/4112 [==============================] - 2s 423us/sample - loss: 0.4945 - val_loss: 0.5060
# Epoch 15/100
# 4112/4112 [==============================] - 2s 416us/sample - loss: 0.4930 - val_loss: 0.4960
# Epoch 16/100
# 4112/4112 [==============================] - 2s 421us/sample - loss: 0.4896 - val_loss: 0.5029
# Epoch 17/100
# 4112/4112 [==============================] - 2s 416us/sample - loss: 0.4868 - val_loss: 0.5132
# Epoch 18/100
# 4112/4112 [==============================] - 2s 418us/sample - loss: 0.4841 - val_loss: 0.5033
# Epoch 19/100
# 4112/4112 [==============================] - 2s 419us/sample - loss: 0.4815 - val_loss: 0.5047
# Epoch 20/100
# 4112/4112 [==============================] - 2s 415us/sample - loss: 0.4792 - val_loss: 0.5047
# Epoch 21/100
# 4112/4112 [==============================] - 2s 415us/sample - loss: 0.4775 - val_loss: 0.5012
# Epoch 22/100
# 4112/4112 [==============================] - 2s 417us/sample - loss: 0.4739 - val_loss: 0.5058
# Epoch 23/100
# 4112/4112 [==============================] - 2s 418us/sample - loss: 0.4719 - val_loss: 0.5051
# Epoch 24/100
# 4112/4112 [==============================] - 2s 419us/sample - loss: 0.4710 - val_loss: 0.5119
# Epoch 25/100
# 4112/4112 [==============================] - 2s 447us/sample - loss: 0.4678 - val_loss: 0.5049
# Epoch 26/100
# 4112/4112 [==============================] - 2s 448us/sample - loss: 0.4646 - val_loss: 0.5060
# Epoch 27/100
# 4112/4112 [==============================] - 2s 438us/sample - loss: 0.4639 - val_loss: 0.5099
# Epoch 28/100
# 4112/4112 [==============================] - 2s 408us/sample - loss: 0.4635 - val_loss: 0.5067
# Epoch 29/100
# 4112/4112 [==============================] - 2s 406us/sample - loss: 0.4592 - val_loss: 0.5080
# Epoch 30/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4543 - val_loss: 0.5190
# Epoch 31/100
# 4112/4112 [==============================] - 2s 406us/sample - loss: 0.4549 - val_loss: 0.5168
# Epoch 32/100
# 4112/4112 [==============================] - 2s 405us/sample - loss: 0.4509 - val_loss: 0.5156
# Epoch 33/100
# 4112/4112 [==============================] - 2s 409us/sample - loss: 0.4486 - val_loss: 0.5176
# Epoch 34/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4501 - val_loss: 0.5167
# Epoch 35/100
# 4112/4112 [==============================] - 2s 417us/sample - loss: 0.4457 - val_loss: 0.5129
# Epoch 36/100
# 4112/4112 [==============================] - 2s 408us/sample - loss: 0.4426 - val_loss: 0.5202
# Epoch 37/100
# 4112/4112 [==============================] - 2s 406us/sample - loss: 0.4407 - val_loss: 0.5176
# Epoch 38/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4396 - val_loss: 0.5199
# Epoch 39/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4381 - val_loss: 0.5206
# Epoch 40/100
# 4112/4112 [==============================] - 2s 406us/sample - loss: 0.4345 - val_loss: 0.5195
# Epoch 41/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4342 - val_loss: 0.5165
# Epoch 42/100
# 4112/4112 [==============================] - 2s 411us/sample - loss: 0.4327 - val_loss: 0.5235
# Epoch 43/100
# 4112/4112 [==============================] - 2s 410us/sample - loss: 0.4274 - val_loss: 0.5306
# Epoch 44/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4305 - val_loss: 0.5256
# Epoch 45/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4238 - val_loss: 0.5218
# Epoch 46/100
# 4112/4112 [==============================] - 2s 426us/sample - loss: 0.4235 - val_loss: 0.5259
# Epoch 47/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4239 - val_loss: 0.5273
# Epoch 48/100
# 4112/4112 [==============================] - 2s 408us/sample - loss: 0.4211 - val_loss: 0.5274
# Epoch 49/100
# 4112/4112 [==============================] - 2s 411us/sample - loss: 0.4176 - val_loss: 0.5229
# Epoch 50/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4167 - val_loss: 0.5415
# Epoch 51/100
# 4112/4112 [==============================] - 2s 410us/sample - loss: 0.4167 - val_loss: 0.5299
# Epoch 52/100
# 4112/4112 [==============================] - 2s 408us/sample - loss: 0.4125 - val_loss: 0.5308
# Epoch 53/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4118 - val_loss: 0.5322
# Epoch 54/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4127 - val_loss: 0.5323
# Epoch 55/100
# 4112/4112 [==============================] - 2s 406us/sample - loss: 0.4074 - val_loss: 0.5386
# Epoch 56/100
# 4112/4112 [==============================] - 2s 425us/sample - loss: 0.4065 - val_loss: 0.5388
# Epoch 57/100
# 4112/4112 [==============================] - 2s 408us/sample - loss: 0.4070 - val_loss: 0.5347
# Epoch 58/100
# 4112/4112 [==============================] - 2s 408us/sample - loss: 0.4029 - val_loss: 0.5428
# Epoch 59/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.4030 - val_loss: 0.5351
# Epoch 60/100
# 4112/4112 [==============================] - 2s 411us/sample - loss: 0.4021 - val_loss: 0.5349
# Epoch 61/100
# 4112/4112 [==============================] - 2s 414us/sample - loss: 0.3981 - val_loss: 0.5423
# Epoch 62/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3974 - val_loss: 0.5365
# Epoch 63/100
# 4112/4112 [==============================] - 2s 406us/sample - loss: 0.3982 - val_loss: 0.5426
# Epoch 64/100
# 4112/4112 [==============================] - 2s 406us/sample - loss: 0.3946 - val_loss: 0.5426
# Epoch 65/100
# 4112/4112 [==============================] - 2s 409us/sample - loss: 0.3960 - val_loss: 0.5434
# Epoch 66/100
# 4112/4112 [==============================] - 2s 411us/sample - loss: 0.3949 - val_loss: 0.5425
# Epoch 67/100
# 4112/4112 [==============================] - 2s 405us/sample - loss: 0.3924 - val_loss: 0.5373
# Epoch 68/100
# 4112/4112 [==============================] - 2s 410us/sample - loss: 0.3894 - val_loss: 0.5417
# Epoch 69/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3921 - val_loss: 0.5475
# Epoch 70/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3877 - val_loss: 0.5445
# Epoch 71/100
# 4112/4112 [==============================] - 2s 433us/sample - loss: 0.3865 - val_loss: 0.5490
# Epoch 72/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3856 - val_loss: 0.5459
# Epoch 73/100
# 4112/4112 [==============================] - 2s 405us/sample - loss: 0.3863 - val_loss: 0.5453
# Epoch 74/100
# 4112/4112 [==============================] - 2s 410us/sample - loss: 0.3847 - val_loss: 0.5532
# Epoch 75/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3828 - val_loss: 0.5477
# Epoch 76/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3820 - val_loss: 0.5502
# Epoch 77/100
# 4112/4112 [==============================] - 2s 405us/sample - loss: 0.3795 - val_loss: 0.5583
# Epoch 78/100
# 4112/4112 [==============================] - 2s 404us/sample - loss: 0.3800 - val_loss: 0.5536
# Epoch 79/100
# 4112/4112 [==============================] - 2s 408us/sample - loss: 0.3781 - val_loss: 0.5481
# Epoch 80/100
# 4112/4112 [==============================] - 2s 414us/sample - loss: 0.3767 - val_loss: 0.5481
# Epoch 81/100
# 4112/4112 [==============================] - 2s 416us/sample - loss: 0.3770 - val_loss: 0.5553
# Epoch 82/100
# 4112/4112 [==============================] - 2s 427us/sample - loss: 0.3725 - val_loss: 0.5522
# Epoch 83/100
# 4112/4112 [==============================] - 2s 405us/sample - loss: 0.3743 - val_loss: 0.5565
# Epoch 84/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3726 - val_loss: 0.5593
# Epoch 85/100
# 4112/4112 [==============================] - 2s 405us/sample - loss: 0.3730 - val_loss: 0.5520
# Epoch 86/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3713 - val_loss: 0.5576
# Epoch 87/100
# 4112/4112 [==============================] - 2s 403us/sample - loss: 0.3731 - val_loss: 0.5604
# Epoch 88/100
# 4112/4112 [==============================] - 2s 405us/sample - loss: 0.3703 - val_loss: 0.5485
# Epoch 89/100
# 4112/4112 [==============================] - 2s 406us/sample - loss: 0.3681 - val_loss: 0.5541
# Epoch 90/100
# 4112/4112 [==============================] - 2s 406us/sample - loss: 0.3690 - val_loss: 0.5635
# Epoch 91/100
# 4112/4112 [==============================] - 2s 408us/sample - loss: 0.3695 - val_loss: 0.5585
# Epoch 92/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3665 - val_loss: 0.5599
# Epoch 93/100
# 4112/4112 [==============================] - 2s 405us/sample - loss: 0.3675 - val_loss: 0.5590
# Epoch 94/100
# 4112/4112 [==============================] - 2s 410us/sample - loss: 0.3648 - val_loss: 0.5606
# Epoch 95/100
# 4112/4112 [==============================] - 2s 409us/sample - loss: 0.3633 - val_loss: 0.5614
# Epoch 96/100
# 4112/4112 [==============================] - 2s 406us/sample - loss: 0.3607 - val_loss: 0.5619
# Epoch 97/100
# 4112/4112 [==============================] - 2s 405us/sample - loss: 0.3614 - val_loss: 0.5622
# Epoch 98/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3626 - val_loss: 0.5642
# Epoch 99/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3598 - val_loss: 0.5595
# Epoch 100/100
# 4112/4112 [==============================] - 2s 407us/sample - loss: 0.3599 - val_loss: 0.5640

# %% [markdown]
# 预测

# %%
# model.save(r'trained_models/mlp_0.775.h5')
# model.save(r'trained_models/gene_mlp_0.752.h5')

# %%
def recursive_predict(model, X_test, n_inputs, n_features, total_timesteps):
    # 只能用每个里面的第一部分，其他用预测来填充
    gap = total_timesteps - n_inputs
    y_pred = []
    i = 0
    while i < len(X_test):
        history = [num for num in X_test[i]]
        i += gap
        inner_pred = []
        for j in range(total_timesteps - n_inputs):
            X = np.array(history[-n_features * n_inputs:]).reshape(1, n_features * n_inputs)
            pred = list(model.predict(X)[0])
            inner_pred.append(pred[-2])
            history += pred
        y_pred.append(np.array(inner_pred))
    return np.array(y_pred)

# %%
y_pred = recursive_predict(model, X_test, 11, 10, 16)
# train_pred = recursive_predict(model, X_train, 11, 10, 16)
# y_pred = model.predict(Xs_train).reshape(y_train.shape)

# %% [markdown]
# 画图

# %%
y_pred.shape
# Out:
# (529, 5)

# %%
X_train, X_test, y_train, y_test, ids_train, ids_test = split_data_with_index(data, n_input=11, ratio=0.2)

# %%
# 训练集
ids = random.sample(range(len(y_test)), 10)

plt.figure(figsize=(12,8))
for i in range(10):
    plt.subplot(5,2,i+1)
    plt.plot(np.concatenate((X_train[ids[i], :, -2], y_train[ids[i]].reshape(-1)), axis=None), label='actual', zorder=1)
    plt.plot(np.concatenate((X_train[ids[i], :, -2], y_pred[ids[i]].reshape(-1)), axis=None), label='predict', zorder=0)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# 测试集
ids = random.sample(range(len(y_test)), 10)

plt.figure(figsize=(12,8))
for i in range(10):
    plt.subplot(5,2,i+1)
    plt.plot(np.concatenate((X_test[ids[i], :, -2], y_test[ids[i]].reshape(-1)), axis=None), label='actual', zorder=1)
    plt.plot(np.concatenate((X_test[ids[i], :, -2], y_pred[ids[i]].reshape(-1)), axis=None), label='predict', zorder=0)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 评估

# %%
metrics = ['mae', 'ndcg']

for m in metrics:
    overall, annual = eval_model(m, y_test, y_pred, scaler)
    print('{}:'.format(m.upper()), overall)
    print('{}MAE:'.format(m.upper()),annual)
    plt.plot(annual)
    plt.show()
# Out:
# MAE: 0.7522511270455224
# MAEMAE: [0.4080222  0.60508033 0.78969065 0.89789823 1.06056423]
# NDCG: 0.45562953252086746
# NDCGMAE: [0.33766659894011164, 0.3026187140239567, 0.002532929145385423, 0.030869366766204557, 0.014348797121529849]
# C:\Users\Tom Leung\OneDrive\文件\武汉大学\硕士投稿\主题热度预测\program\utils.py:36: RuntimeWarning: invalid value encountered in true_divide
#   pred_score = np.sum((2 ** pred_array[:, 1] - 1) / np.log2(pred_array[:, 0] + 1))

# %%
_y_true, _y_pred = eval_model('classification', y_test, y_pred, scaler)

# %%
from sklearn.metrics import classification_report
print(classification_report(_y_true.reshape(-1), _y_pred.reshape(-1)))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.86      0.86      0.86      3600
#          2.0       0.33      0.33      0.33       770
#          3.0       0.33      0.33      0.33       515
#          4.0       0.40      0.40      0.40       260
#
#     accuracy                           0.70      5145
#    macro avg       0.48      0.48      0.48      5145
# weighted avg       0.70      0.70      0.70      5145

# %%
errors = np.abs((y_test - y_pred) / y_test)
annual_mape = np.mean(errors, axis=0)
overall_mape = np.mean(errors, axis=None)
overall_mape
# Out:
# 3.646415186256733
