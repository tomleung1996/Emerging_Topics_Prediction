# %% [markdown]
# ### 前馈神经网络模型
# 两种方式，一种是循环预测，一种是直接出N年
#
# 0.758 gene MAE
#
# 0.718 transplant MAE

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from utils import *
import tensorflow.keras as keras
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


random.seed(42)

# %% [markdown]
# 读取数据

# %%
# (term_num, time_steps, feature_num)

gene_arr_path = r'../output/gene_editing/es_with_decay.array'
transplant_arr_path = r'../output/transplant/es_with_decay.array'

gene_arr = pickle.load(open(gene_arr_path, mode='rb'))
transplant_arr = pickle.load(open(transplant_arr_path, mode='rb'))

print('Shape of the gene_editing array:',gene_arr.shape)
print('Shape of the transplant array:',transplant_arr.shape)
# Out:
# Shape of the gene_editing array: (2643, 17, 10)
# Shape of the transplant array: (5141, 17, 10)

# %% [markdown]
# ### 截断数据
# 因2019年两个数据集的EmergingScore大部分都为0，而2018年及之前的情况要好很多，故抛弃2019年数据

# %%
gene_arr = gene_arr[:, :-1, :]
transplant_arr = transplant_arr[:, :-1, :]

print('Shape of the gene_editing array:',gene_arr.shape)
print('Shape of the transplant array:',transplant_arr.shape)
# Out:
# Shape of the gene_editing array: (2643, 16, 10)
# Shape of the transplant array: (5141, 16, 10)

# %% [markdown]
# ### 规范数据并获取训练集和测试集
# 这里的训练集、测试集和序列模型的不同，是滑动窗口
#
# 为了保证可比性，使用位置号来标明原来的序列
#
# 因为不是序列模型，所以需要展平多变量序列，也可以使用多个神经网络对每一维进行处理
#
# 此外，因为是多变量序列，所以模型要预测所有的变量，不然没法循环输入
#
# https://machinelearningmastery.com/how-to-develop-multilayer-perceptron-models-for-time-series-forecasting/

# %%
def to_supervised(data, n_inputs, ids_train, ids_test):
    train_data = data[ids_train]
    test_data = data[ids_test]
    
    X_train = list()
    X_test = list()
    y_train = list()
    y_test = list()
    
    for train in train_data:
        for i in range(len(train_data[0]) - n_inputs):
            X_train.append(train[i:i+n_inputs].flatten())
            y_train.append(train[i+n_inputs].flatten())
    
    for test in test_data:
        for i in range(len(test_data[0]) - n_inputs):
            X_test.append(test[i:i+n_inputs].flatten())
            y_test.append(test[i+n_inputs].flatten())
    
    return np.array(X_train), np.array(X_test), np.array(y_train), np.array(y_test)

# %%
def split_data_by_trend(data, data_ids):
    # 和RNN的不一样，这里用到ID
    up_data_ids = []
    down_data_ids = []
    
    for data_id in data_ids:
        a, b = np.polyfit(range(len(data[data_id])), data[data_id, :, -2].reshape(-1), 1)
        if a > 0:
            up_data_ids.append(data_id)
        else:
            down_data_ids.append(data_id)
            
    return up_data_ids, down_data_ids

# %%
scaler, data = scale_data(gene_arr, 'standard')
# scaler, data = scale_data(transplant_arr, 'standard')
X_train, X_test, y_train, y_test, ids_train, ids_test = split_data_with_index(data, n_input=11, ratio=0.2)

# 如果不是循环预测则不需要执行下面这一行
# X_train, X_test, y_train, y_test = to_supervised(data, 11, ids_train, ids_test)

# %%
train_up_ids, train_down_ids = split_data_by_trend(data, ids_train)
test_up_ids, test_down_ids = split_data_by_trend(data, ids_test)

X_train1, X_test1, y_train1, y_test1 = to_supervised(data, 11, train_up_ids, test_up_ids)
X_train2, X_test2, y_train2, y_test2 = to_supervised(data, 11, train_down_ids, test_down_ids)

# %% [markdown]
# ### 构建模型

# %%
def build_recursive_dnn_model():
    model = keras.models.Sequential()
#     model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu', input_shape=(X_train1.shape[1],)))
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(y_train1.shape[1]))
    model.compile(loss='mae', optimizer='rmsprop')
    return model

def build_direct_dnn_model():
    model = keras.models.Sequential()
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(y_train.shape[1]))
    model.compile(loss='mae', optimizer='rmsprop')
    return model

def build_parallel_dnn_model(n_inputs, n_vars):
    var = []
    denses = []
    
    for i in range(n_vars):
        v = Input(shape=(n_inputs))
        d = Dense(256, activation='relu')(v)
        var.append(v)
        denses.append(d)
    
    merge = concatenate(denses)
    d_2 = Dense(128)(merge)
    output = Dense(5)(d_2)
    
    model = Model(inputs=var, outputs=output)
    model.compile(loss='mae', optimizer='rmsprop')
    
    return model

def build_parallel_X(data):
    Xs = []
    for i in range(data.shape[2]):
        Xs.append(data[:, :, i])
    return Xs

# %% [markdown]
# 训练

# %%
train_xs = [X_train1, X_train2]
train_ys = [y_train1, y_train2]
test_xs = [X_test1, X_test2]
test_ys = [y_test1, y_test2]
i_s = [1, 2]

# %%
for train_x, train_y, test_x, test_y, i in zip(train_xs, train_ys, test_xs, test_ys, i_s):
    model = build_recursive_dnn_model()
    history = model.fit(train_x, train_y, epochs=100, batch_size=16, verbose=1, validation_data=(test_x, test_y), 
                   callbacks=[
                       ModelCheckpoint('mlp_model{}_checkpoint.h5'.format(i), save_best_only=True,verbose=1)
                   ])
# Out:
# Train on 10445 samples, validate on 2610 samples
# Epoch 1/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.2805
# Epoch 00001: val_loss improved from inf to 0.24815, saving model to mlp_model1_checkpoint.h5
# 10445/10445 [==============================] - 3s 281us/sample - loss: 0.2804 - val_loss: 0.2481
# Epoch 2/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.2610
# Epoch 00002: val_loss improved from 0.24815 to 0.24628, saving model to mlp_model1_checkpoint.h5
# 10445/10445 [==============================] - 2s 167us/sample - loss: 0.2611 - val_loss: 0.2463
# Epoch 3/100
# 10080/10445 [===========================>..] - ETA: 0s - loss: 0.2573
# Epoch 00003: val_loss improved from 0.24628 to 0.24233, saving model to mlp_model1_checkpoint.h5
# 10445/10445 [==============================] - 2s 169us/sample - loss: 0.2572 - val_loss: 0.2423
# Epoch 4/100
# 10384/10445 [============================>.] - ETA: 0s - loss: 0.2531
# Epoch 00004: val_loss did not improve from 0.24233
# 10445/10445 [==============================] - 2s 166us/sample - loss: 0.2530 - val_loss: 0.2440
# Epoch 5/100
# 10400/10445 [============================>.] - ETA: 0s - loss: 0.2513
# Epoch 00005: val_loss improved from 0.24233 to 0.23987, saving model to mlp_model1_checkpoint.h5
# 10445/10445 [==============================] - 2s 168us/sample - loss: 0.2513 - val_loss: 0.2399
# Epoch 6/100
# 10208/10445 [============================>.] - ETA: 0s - loss: 0.2456
# Epoch 00006: val_loss improved from 0.23987 to 0.23910, saving model to mlp_model1_checkpoint.h5
# 10445/10445 [==============================] - 2s 170us/sample - loss: 0.2452 - val_loss: 0.2391
# Epoch 7/100
# 10352/10445 [============================>.] - ETA: 0s - loss: 0.2469
# Epoch 00007: val_loss did not improve from 0.23910
# 10445/10445 [==============================] - 2s 178us/sample - loss: 0.2470 - val_loss: 0.2401
# Epoch 8/100
# 10320/10445 [============================>.] - ETA: 0s - loss: 0.2432
# Epoch 00008: val_loss did not improve from 0.23910
# 10445/10445 [==============================] - 2s 173us/sample - loss: 0.2429 - val_loss: 0.2397
# Epoch 9/100
# 10320/10445 [============================>.] - ETA: 0s - loss: 0.2465
# Epoch 00009: val_loss did not improve from 0.23910
# 10445/10445 [==============================] - 2s 193us/sample - loss: 0.2456 - val_loss: 0.2396
# Epoch 10/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.2402
# Epoch 00010: val_loss did not improve from 0.23910
# 10445/10445 [==============================] - 2s 212us/sample - loss: 0.2401 - val_loss: 0.2417
# Epoch 11/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.2392
# Epoch 00011: val_loss did not improve from 0.23910
# 10445/10445 [==============================] - 2s 212us/sample - loss: 0.2394 - val_loss: 0.2430
# Epoch 12/100
# 10304/10445 [============================>.] - ETA: 0s - loss: 0.2383
# Epoch 00012: val_loss did not improve from 0.23910
# 10445/10445 [==============================] - 2s 213us/sample - loss: 0.2382 - val_loss: 0.2397
# Epoch 13/100
# 10240/10445 [============================>.] - ETA: 0s - loss: 0.2374
# Epoch 00013: val_loss did not improve from 0.23910
# 10445/10445 [==============================] - 2s 215us/sample - loss: 0.2384 - val_loss: 0.2418
# Epoch 14/100
# 10288/10445 [============================>.] - ETA: 0s - loss: 0.2342
# Epoch 00014: val_loss did not improve from 0.23910
# 10445/10445 [==============================] - 2s 214us/sample - loss: 0.2344 - val_loss: 0.2441
# Epoch 15/100
# 10400/10445 [============================>.] - ETA: 0s - loss: 0.2387
# Epoch 00015: val_loss did not improve from 0.23910
# 10445/10445 [==============================] - 2s 218us/sample - loss: 0.2387 - val_loss: 0.2429
# Epoch 16/100
# 10336/10445 [============================>.] - ETA: 0s - loss: 0.2339
# Epoch 00016: val_loss did not improve from 0.23910
# 10445/10445 [==============================] - 2s 218us/sample - loss: 0.2336 - val_loss: 0.2417
# Epoch 17/100
# 10320/10445 [============================>.] - ETA: 0s - loss: 0.2351
# Epoch 00017: val_loss did not improve from 0.23910
# 10445/10445 [==============================] - 2s 214us/sample - loss: 0.2351 - val_loss: 0.2415
# Epoch 18/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.2309
# Epoch 00018: val_loss improved from 0.23910 to 0.23823, saving model to mlp_model1_checkpoint.h5
# 10445/10445 [==============================] - 2s 213us/sample - loss: 0.2309 - val_loss: 0.2382
# Epoch 19/100
# 10384/10445 [============================>.] - ETA: 0s - loss: 0.2307
# Epoch 00019: val_loss improved from 0.23823 to 0.23713, saving model to mlp_model1_checkpoint.h5
# 10445/10445 [==============================] - 2s 214us/sample - loss: 0.2305 - val_loss: 0.2371
# Epoch 20/100
# 10256/10445 [============================>.] - ETA: 0s - loss: 0.2336
# Epoch 00020: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 215us/sample - loss: 0.2333 - val_loss: 0.2395
# Epoch 21/100
# 10368/10445 [============================>.] - ETA: 0s - loss: 0.2287
# Epoch 00021: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 213us/sample - loss: 0.2284 - val_loss: 0.2379
# Epoch 22/100
# 10320/10445 [============================>.] - ETA: 0s - loss: 0.2334
# Epoch 00022: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 213us/sample - loss: 0.2328 - val_loss: 0.2416
# Epoch 23/100
# 10368/10445 [============================>.] - ETA: 0s - loss: 0.2305
# Epoch 00023: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 212us/sample - loss: 0.2306 - val_loss: 0.2395
# Epoch 24/100
# 10304/10445 [============================>.] - ETA: 0s - loss: 0.2253
# Epoch 00024: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 214us/sample - loss: 0.2257 - val_loss: 0.2421
# Epoch 25/100
# 10320/10445 [============================>.] - ETA: 0s - loss: 0.2267
# Epoch 00025: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 228us/sample - loss: 0.2263 - val_loss: 0.2395
# Epoch 26/100
# 10192/10445 [============================>.] - ETA: 0s - loss: 0.2249
# Epoch 00026: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 216us/sample - loss: 0.2246 - val_loss: 0.2379
# Epoch 27/100
# 10384/10445 [============================>.] - ETA: 0s - loss: 0.2229
# Epoch 00027: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 230us/sample - loss: 0.2246 - val_loss: 0.2381
# Epoch 28/100
# 10224/10445 [============================>.] - ETA: 0s - loss: 0.2274
# Epoch 00028: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 221us/sample - loss: 0.2274 - val_loss: 0.2399
# Epoch 29/100
# 10304/10445 [============================>.] - ETA: 0s - loss: 0.2237
# Epoch 00029: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 214us/sample - loss: 0.2233 - val_loss: 0.2424
# Epoch 30/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.2190
# Epoch 00030: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 213us/sample - loss: 0.2191 - val_loss: 0.2393
# Epoch 31/100
# 10192/10445 [============================>.] - ETA: 0s - loss: 0.2196
# Epoch 00031: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 211us/sample - loss: 0.2195 - val_loss: 0.2409
# Epoch 32/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.2210
# Epoch 00032: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 212us/sample - loss: 0.2210 - val_loss: 0.2448
# Epoch 33/100
# 10256/10445 [============================>.] - ETA: 0s - loss: 0.2195
# Epoch 00033: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 211us/sample - loss: 0.2192 - val_loss: 0.2396
# Epoch 34/100
# 10192/10445 [============================>.] - ETA: 0s - loss: 0.2194
# Epoch 00034: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 211us/sample - loss: 0.2197 - val_loss: 0.2402
# Epoch 35/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.2221
# Epoch 00035: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.2220 - val_loss: 0.2445
# Epoch 36/100
# 10192/10445 [============================>.] - ETA: 0s - loss: 0.2147
# Epoch 00036: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 205us/sample - loss: 0.2148 - val_loss: 0.2414
# Epoch 37/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.2203
# Epoch 00037: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.2203 - val_loss: 0.2423
# Epoch 38/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.2166
# Epoch 00038: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2167 - val_loss: 0.2392
# Epoch 39/100
# 10192/10445 [============================>.] - ETA: 0s - loss: 0.2148
# Epoch 00039: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 210us/sample - loss: 0.2148 - val_loss: 0.2426
# Epoch 40/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.2173
# Epoch 00040: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.2169 - val_loss: 0.2414
# Epoch 41/100
# 10192/10445 [============================>.] - ETA: 0s - loss: 0.2166
# Epoch 00041: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 205us/sample - loss: 0.2164 - val_loss: 0.2432
# Epoch 42/100
# 10352/10445 [============================>.] - ETA: 0s - loss: 0.2131
# Epoch 00042: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 209us/sample - loss: 0.2129 - val_loss: 0.2388
# Epoch 43/100
# 10224/10445 [============================>.] - ETA: 0s - loss: 0.2216
# Epoch 00043: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 204us/sample - loss: 0.2218 - val_loss: 0.2411
# Epoch 44/100
# 10176/10445 [============================>.] - ETA: 0s - loss: 0.2150
# Epoch 00044: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 205us/sample - loss: 0.2152 - val_loss: 0.2402
# Epoch 45/100
# 10384/10445 [============================>.] - ETA: 0s - loss: 0.2148
# Epoch 00045: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2148 - val_loss: 0.2419
# Epoch 46/100
# 10288/10445 [============================>.] - ETA: 0s - loss: 0.2141
# Epoch 00046: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 210us/sample - loss: 0.2139 - val_loss: 0.2403
# Epoch 47/100
# 10368/10445 [============================>.] - ETA: 0s - loss: 0.2145
# Epoch 00047: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 214us/sample - loss: 0.2142 - val_loss: 0.2430
# Epoch 48/100
# 10368/10445 [============================>.] - ETA: 0s - loss: 0.2113
# Epoch 00048: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2108 - val_loss: 0.2415
# Epoch 49/100
# 10368/10445 [============================>.] - ETA: 0s - loss: 0.2115
# Epoch 00049: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 208us/sample - loss: 0.2114 - val_loss: 0.2401
# Epoch 50/100
# 10400/10445 [============================>.] - ETA: 0s - loss: 0.2094
# Epoch 00050: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2094 - val_loss: 0.2466
# Epoch 51/100
# 10144/10445 [============================>.] - ETA: 0s - loss: 0.2139
# Epoch 00051: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.2137 - val_loss: 0.2439
# Epoch 52/100
# 10176/10445 [============================>.] - ETA: 0s - loss: 0.2102
# Epoch 00052: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 210us/sample - loss: 0.2101 - val_loss: 0.2421
# Epoch 53/100
# 10336/10445 [============================>.] - ETA: 0s - loss: 0.2084
# Epoch 00053: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 208us/sample - loss: 0.2082 - val_loss: 0.2438
# Epoch 54/100
# 10272/10445 [============================>.] - ETA: 0s - loss: 0.2058
# Epoch 00054: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 209us/sample - loss: 0.2056 - val_loss: 0.2422
# Epoch 55/100
# 10400/10445 [============================>.] - ETA: 0s - loss: 0.2072
# Epoch 00055: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 209us/sample - loss: 0.2073 - val_loss: 0.2411
# Epoch 56/100
# 10336/10445 [============================>.] - ETA: 0s - loss: 0.2062
# Epoch 00056: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 208us/sample - loss: 0.2062 - val_loss: 0.2381
# Epoch 57/100
# 10160/10445 [============================>.] - ETA: 0s - loss: 0.2044
# Epoch 00057: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.2041 - val_loss: 0.2388
# Epoch 58/100
# 10192/10445 [============================>.] - ETA: 0s - loss: 0.2071
# Epoch 00058: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2070 - val_loss: 0.2409
# Epoch 59/100
# 10400/10445 [============================>.] - ETA: 0s - loss: 0.2056
# Epoch 00059: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2056 - val_loss: 0.2388
# Epoch 60/100
# 10400/10445 [============================>.] - ETA: 0s - loss: 0.2048
# Epoch 00060: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2049 - val_loss: 0.2419
# Epoch 61/100
# 10160/10445 [============================>.] - ETA: 0s - loss: 0.2026
# Epoch 00061: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.2025 - val_loss: 0.2447
# Epoch 62/100
# 10368/10445 [============================>.] - ETA: 0s - loss: 0.2037
# Epoch 00062: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 208us/sample - loss: 0.2038 - val_loss: 0.2433
# Epoch 63/100
# 10384/10445 [============================>.] - ETA: 0s - loss: 0.2026
# Epoch 00063: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2034 - val_loss: 0.2438
# Epoch 64/100
# 10208/10445 [============================>.] - ETA: 0s - loss: 0.2027
# Epoch 00064: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 210us/sample - loss: 0.2027 - val_loss: 0.2423
# Epoch 65/100
# 10384/10445 [============================>.] - ETA: 0s - loss: 0.2054
# Epoch 00065: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2053 - val_loss: 0.2425
# Epoch 66/100
# 10368/10445 [============================>.] - ETA: 0s - loss: 0.2033
# Epoch 00066: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2031 - val_loss: 0.2434
# Epoch 67/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.2019
# Epoch 00067: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2021 - val_loss: 0.2419
# Epoch 68/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.2018
# Epoch 00068: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.2017 - val_loss: 0.2397
# Epoch 69/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.1999
# Epoch 00069: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1998 - val_loss: 0.2400
# Epoch 70/100
# 10192/10445 [============================>.] - ETA: 0s - loss: 0.2002
# Epoch 00070: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 210us/sample - loss: 0.2002 - val_loss: 0.2458
# Epoch 71/100
# 10176/10445 [============================>.] - ETA: 0s - loss: 0.1989
# Epoch 00071: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 205us/sample - loss: 0.1987 - val_loss: 0.2447
# Epoch 72/100
# 10192/10445 [============================>.] - ETA: 0s - loss: 0.2017
# Epoch 00072: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 205us/sample - loss: 0.2018 - val_loss: 0.2416
# Epoch 73/100
# 10256/10445 [============================>.] - ETA: 0s - loss: 0.2003
# Epoch 00073: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 204us/sample - loss: 0.2003 - val_loss: 0.2414
# Epoch 74/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.1979
# Epoch 00074: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.1979 - val_loss: 0.2450
# Epoch 75/100
# 10192/10445 [============================>.] - ETA: 0s - loss: 0.2043
# Epoch 00075: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.2034 - val_loss: 0.2452
# Epoch 76/100
# 10288/10445 [============================>.] - ETA: 0s - loss: 0.1999
# Epoch 00076: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 210us/sample - loss: 0.1994 - val_loss: 0.2434
# Epoch 77/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.1974
# Epoch 00077: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1974 - val_loss: 0.2419
# Epoch 78/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.1987
# Epoch 00078: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1987 - val_loss: 0.2445
# Epoch 79/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.1984
# Epoch 00079: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.1983 - val_loss: 0.2469
# Epoch 80/100
# 10176/10445 [============================>.] - ETA: 0s - loss: 0.1969
# Epoch 00080: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 205us/sample - loss: 0.1970 - val_loss: 0.2445
# Epoch 81/100
# 10144/10445 [============================>.] - ETA: 0s - loss: 0.2014
# Epoch 00081: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.2008 - val_loss: 0.2419
# Epoch 82/100
# 10368/10445 [============================>.] - ETA: 0s - loss: 0.1995
# Epoch 00082: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.1995 - val_loss: 0.2410
# Epoch 83/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.1965
# Epoch 00083: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1965 - val_loss: 0.2445
# Epoch 84/100
# 10160/10445 [============================>.] - ETA: 0s - loss: 0.1940
# Epoch 00084: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 205us/sample - loss: 0.1944 - val_loss: 0.2421
# Epoch 85/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.1953
# Epoch 00085: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1953 - val_loss: 0.2426
# Epoch 86/100
# 10288/10445 [============================>.] - ETA: 0s - loss: 0.2022
# Epoch 00086: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 208us/sample - loss: 0.2017 - val_loss: 0.2396
# Epoch 87/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.1957
# Epoch 00087: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.1957 - val_loss: 0.2424
# Epoch 88/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.1963
# Epoch 00088: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.1965 - val_loss: 0.2400
# Epoch 89/100
# 10176/10445 [============================>.] - ETA: 0s - loss: 0.1946
# Epoch 00089: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 211us/sample - loss: 0.1946 - val_loss: 0.2458
# Epoch 90/100
# 10176/10445 [============================>.] - ETA: 0s - loss: 0.1941
# Epoch 00090: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.1941 - val_loss: 0.2418
# Epoch 91/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.1924
# Epoch 00091: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 206us/sample - loss: 0.1923 - val_loss: 0.2416
# Epoch 92/100
# 10160/10445 [============================>.] - ETA: 0s - loss: 0.1930
# Epoch 00092: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1932 - val_loss: 0.2441
# Epoch 93/100
# 10432/10445 [============================>.] - ETA: 0s - loss: 0.1960
# Epoch 00093: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1959 - val_loss: 0.2419
# Epoch 94/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.1940
# Epoch 00094: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1942 - val_loss: 0.2426
# Epoch 95/100
# 10368/10445 [============================>.] - ETA: 0s - loss: 0.1922
# Epoch 00095: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1928 - val_loss: 0.2439
# Epoch 96/100
# 10368/10445 [============================>.] - ETA: 0s - loss: 0.1913
# Epoch 00096: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1912 - val_loss: 0.2433
# Epoch 97/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.1924
# Epoch 00097: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1925 - val_loss: 0.2445
# Epoch 98/100
# 10160/10445 [============================>.] - ETA: 0s - loss: 0.1889
# Epoch 00098: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 211us/sample - loss: 0.1892 - val_loss: 0.2435
# Epoch 99/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.1929
# Epoch 00099: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1929 - val_loss: 0.2415
# Epoch 100/100
# 10416/10445 [============================>.] - ETA: 0s - loss: 0.1909
# Epoch 00100: val_loss did not improve from 0.23713
# 10445/10445 [==============================] - 2s 207us/sample - loss: 0.1908 - val_loss: 0.2470
# Train on 125 samples, validate on 35 samples
# Epoch 1/100
#  16/125 [==>...........................] - ETA: 4s - loss: 0.4167
# Epoch 00001: val_loss improved from inf to 0.18261, saving model to mlp_model2_checkpoint.h5
# 125/125 [==============================] - 1s 7ms/sample - loss: 0.2266 - val_loss: 0.1826
# Epoch 2/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.2040
# Epoch 00002: val_loss improved from 0.18261 to 0.15664, saving model to mlp_model2_checkpoint.h5
# 125/125 [==============================] - 0s 638us/sample - loss: 0.1340 - val_loss: 0.1566
# Epoch 3/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.1904
# Epoch 00003: val_loss improved from 0.15664 to 0.14331, saving model to mlp_model2_checkpoint.h5
# 125/125 [==============================] - 0s 670us/sample - loss: 0.1134 - val_loss: 0.1433
# Epoch 4/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.1220
# Epoch 00004: val_loss improved from 0.14331 to 0.13429, saving model to mlp_model2_checkpoint.h5
# 125/125 [==============================] - 0s 694us/sample - loss: 0.1118 - val_loss: 0.1343
# Epoch 5/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.1240
# Epoch 00005: val_loss improved from 0.13429 to 0.13205, saving model to mlp_model2_checkpoint.h5
# 125/125 [==============================] - 0s 702us/sample - loss: 0.1004 - val_loss: 0.1321
# Epoch 6/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.1059
# Epoch 00006: val_loss improved from 0.13205 to 0.12863, saving model to mlp_model2_checkpoint.h5
# 125/125 [==============================] - 0s 702us/sample - loss: 0.0940 - val_loss: 0.1286
# Epoch 7/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0914
# Epoch 00007: val_loss did not improve from 0.12863
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0909 - val_loss: 0.1297
# Epoch 8/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0903
# Epoch 00008: val_loss did not improve from 0.12863
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0860 - val_loss: 0.1326
# Epoch 9/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.1259
# Epoch 00009: val_loss improved from 0.12863 to 0.12656, saving model to mlp_model2_checkpoint.h5
# 125/125 [==============================] - 0s 694us/sample - loss: 0.0849 - val_loss: 0.1266
# Epoch 10/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0693
# Epoch 00010: val_loss did not improve from 0.12656
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0784 - val_loss: 0.1285
# Epoch 11/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0969
# Epoch 00011: val_loss improved from 0.12656 to 0.11869, saving model to mlp_model2_checkpoint.h5
# 125/125 [==============================] - 0s 694us/sample - loss: 0.0785 - val_loss: 0.1187
# Epoch 12/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0524
# Epoch 00012: val_loss did not improve from 0.11869
# 125/125 [==============================] - 0s 598us/sample - loss: 0.0730 - val_loss: 0.1227
# Epoch 13/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0463
# Epoch 00013: val_loss did not improve from 0.11869
# 125/125 [==============================] - 0s 798us/sample - loss: 0.0704 - val_loss: 0.1209
# Epoch 14/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0822
# Epoch 00014: val_loss improved from 0.11869 to 0.11833, saving model to mlp_model2_checkpoint.h5
# 125/125 [==============================] - 0s 878us/sample - loss: 0.0687 - val_loss: 0.1183
# Epoch 15/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0557
# Epoch 00015: val_loss did not improve from 0.11833
# 125/125 [==============================] - 0s 574us/sample - loss: 0.0683 - val_loss: 0.1201
# Epoch 16/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0929
# Epoch 00016: val_loss did not improve from 0.11833
# 125/125 [==============================] - 0s 574us/sample - loss: 0.0629 - val_loss: 0.1285
# Epoch 17/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0632
# Epoch 00017: val_loss did not improve from 0.11833
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0645 - val_loss: 0.1195
# Epoch 18/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0526
# Epoch 00018: val_loss did not improve from 0.11833
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0583 - val_loss: 0.1215
# Epoch 19/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0586
# Epoch 00019: val_loss did not improve from 0.11833
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0608 - val_loss: 0.1199
# Epoch 20/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0672
# Epoch 00020: val_loss did not improve from 0.11833
# 125/125 [==============================] - 0s 582us/sample - loss: 0.0568 - val_loss: 0.1232
# Epoch 21/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0642
# Epoch 00021: val_loss improved from 0.11833 to 0.11823, saving model to mlp_model2_checkpoint.h5
# 125/125 [==============================] - 0s 734us/sample - loss: 0.0583 - val_loss: 0.1182
# Epoch 22/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0818
# Epoch 00022: val_loss did not improve from 0.11823
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0543 - val_loss: 0.1190
# Epoch 23/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0551
# Epoch 00023: val_loss did not improve from 0.11823
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0558 - val_loss: 0.1190
# Epoch 24/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0538
# Epoch 00024: val_loss improved from 0.11823 to 0.11768, saving model to mlp_model2_checkpoint.h5
# 125/125 [==============================] - 0s 742us/sample - loss: 0.0529 - val_loss: 0.1177
# Epoch 25/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0541
# Epoch 00025: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0504 - val_loss: 0.1194
# Epoch 26/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0443
# Epoch 00026: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0483 - val_loss: 0.1177
# Epoch 27/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0523
# Epoch 00027: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0510 - val_loss: 0.1193
# Epoch 28/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0654
# Epoch 00028: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0518 - val_loss: 0.1253
# Epoch 29/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0617
# Epoch 00029: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0447 - val_loss: 0.1286
# Epoch 30/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0443
# Epoch 00030: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0458 - val_loss: 0.1215
# Epoch 31/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0289
# Epoch 00031: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0460 - val_loss: 0.1238
# Epoch 32/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0329
# Epoch 00032: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0441 - val_loss: 0.1292
# Epoch 33/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0394
# Epoch 00033: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 559us/sample - loss: 0.0450 - val_loss: 0.1212
# Epoch 34/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0495
# Epoch 00034: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0418 - val_loss: 0.1232
# Epoch 35/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0317
# Epoch 00035: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 574us/sample - loss: 0.0442 - val_loss: 0.1229
# Epoch 36/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0527
# Epoch 00036: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0416 - val_loss: 0.1216
# Epoch 37/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0502
# Epoch 00037: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0408 - val_loss: 0.1240
# Epoch 38/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0308
# Epoch 00038: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 582us/sample - loss: 0.0415 - val_loss: 0.1232
# Epoch 39/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0500
# Epoch 00039: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 559us/sample - loss: 0.0419 - val_loss: 0.1252
# Epoch 40/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0666
# Epoch 00040: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0390 - val_loss: 0.1257
# Epoch 41/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0369
# Epoch 00041: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0392 - val_loss: 0.1275
# Epoch 42/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0515
# Epoch 00042: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 574us/sample - loss: 0.0380 - val_loss: 0.1325
# Epoch 43/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0345
# Epoch 00043: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 559us/sample - loss: 0.0365 - val_loss: 0.1267
# Epoch 44/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0346
# Epoch 00044: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0370 - val_loss: 0.1231
# Epoch 45/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0388
# Epoch 00045: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 559us/sample - loss: 0.0374 - val_loss: 0.1306
# Epoch 46/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0391
# Epoch 00046: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0366 - val_loss: 0.1268
# Epoch 47/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0396
# Epoch 00047: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 559us/sample - loss: 0.0372 - val_loss: 0.1327
# Epoch 48/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0378
# Epoch 00048: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0355 - val_loss: 0.1233
# Epoch 49/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0253
# Epoch 00049: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0352 - val_loss: 0.1284
# Epoch 50/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0356
# Epoch 00050: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0366 - val_loss: 0.1317
# Epoch 51/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0425
# Epoch 00051: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0390 - val_loss: 0.1306
# Epoch 52/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0296
# Epoch 00052: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0351 - val_loss: 0.1274
# Epoch 53/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0211
# Epoch 00053: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0344 - val_loss: 0.1292
# Epoch 54/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0343
# Epoch 00054: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 559us/sample - loss: 0.0357 - val_loss: 0.1284
# Epoch 55/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0278
# Epoch 00055: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0345 - val_loss: 0.1273
# Epoch 56/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0296
# Epoch 00056: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0319 - val_loss: 0.1324
# Epoch 57/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0293
# Epoch 00057: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0330 - val_loss: 0.1219
# Epoch 58/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0324
# Epoch 00058: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0340 - val_loss: 0.1289
# Epoch 59/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0321
# Epoch 00059: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0319 - val_loss: 0.1270
# Epoch 60/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0248
# Epoch 00060: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0354 - val_loss: 0.1285
# Epoch 61/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0525
# Epoch 00061: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0325 - val_loss: 0.1286
# Epoch 62/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0214
# Epoch 00062: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0319 - val_loss: 0.1241
# Epoch 63/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0300
# Epoch 00063: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0324 - val_loss: 0.1220
# Epoch 64/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0210
# Epoch 00064: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 511us/sample - loss: 0.0322 - val_loss: 0.1283
# Epoch 65/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0214
# Epoch 00065: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0293 - val_loss: 0.1269
# Epoch 66/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0340
# Epoch 00066: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 559us/sample - loss: 0.0298 - val_loss: 0.1293
# Epoch 67/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0193
# Epoch 00067: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0305 - val_loss: 0.1310
# Epoch 68/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0271
# Epoch 00068: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 559us/sample - loss: 0.0314 - val_loss: 0.1272
# Epoch 69/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0342
# Epoch 00069: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0303 - val_loss: 0.1226
# Epoch 70/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0524
# Epoch 00070: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0327 - val_loss: 0.1267
# Epoch 71/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0273
# Epoch 00071: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0291 - val_loss: 0.1308
# Epoch 72/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0232
# Epoch 00072: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 582us/sample - loss: 0.0293 - val_loss: 0.1249
# Epoch 73/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0308
# Epoch 00073: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0311 - val_loss: 0.1196
# Epoch 74/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0294
# Epoch 00074: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0283 - val_loss: 0.1305
# Epoch 75/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0424
# Epoch 00075: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 511us/sample - loss: 0.0313 - val_loss: 0.1302
# Epoch 76/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0276
# Epoch 00076: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0304 - val_loss: 0.1280
# Epoch 77/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0215
# Epoch 00077: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0292 - val_loss: 0.1285
# Epoch 78/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0320
# Epoch 00078: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0305 - val_loss: 0.1305
# Epoch 79/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0424
# Epoch 00079: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0280 - val_loss: 0.1264
# Epoch 80/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0202
# Epoch 00080: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0264 - val_loss: 0.1322
# Epoch 81/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0273
# Epoch 00081: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 551us/sample - loss: 0.0307 - val_loss: 0.1255
# Epoch 82/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0276
# Epoch 00082: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0275 - val_loss: 0.1271
# Epoch 83/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0217
# Epoch 00083: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0267 - val_loss: 0.1247
# Epoch 84/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0452
# Epoch 00084: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0304 - val_loss: 0.1275
# Epoch 85/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0247
# Epoch 00085: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 559us/sample - loss: 0.0271 - val_loss: 0.1317
# Epoch 86/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0230
# Epoch 00086: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 550us/sample - loss: 0.0278 - val_loss: 0.1318
# Epoch 87/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0274
# Epoch 00087: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0275 - val_loss: 0.1279
# Epoch 88/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0445
# Epoch 00088: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0258 - val_loss: 0.1279
# Epoch 89/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0202
# Epoch 00089: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0271 - val_loss: 0.1242
# Epoch 90/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0337
# Epoch 00090: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0264 - val_loss: 0.1307
# Epoch 91/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0414
# Epoch 00091: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0270 - val_loss: 0.1265
# Epoch 92/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0199
# Epoch 00092: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 559us/sample - loss: 0.0263 - val_loss: 0.1289
# Epoch 93/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0351
# Epoch 00093: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0279 - val_loss: 0.1228
# Epoch 94/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0211
# Epoch 00094: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 598us/sample - loss: 0.0249 - val_loss: 0.1294
# Epoch 95/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0183
# Epoch 00095: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 543us/sample - loss: 0.0258 - val_loss: 0.1261
# Epoch 96/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0317
# Epoch 00096: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 535us/sample - loss: 0.0263 - val_loss: 0.1258
# Epoch 97/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0218
# Epoch 00097: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0281 - val_loss: 0.1309
# Epoch 98/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0187
# Epoch 00098: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0249 - val_loss: 0.1297
# Epoch 99/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0286
# Epoch 00099: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 527us/sample - loss: 0.0254 - val_loss: 0.1227
# Epoch 100/100
#  16/125 [==>...........................] - ETA: 0s - loss: 0.0136
# Epoch 00100: val_loss did not improve from 0.11768
# 125/125 [==============================] - 0s 566us/sample - loss: 0.0241 - val_loss: 0.1271

# %% [markdown]
# 预测

# %%
models = []
for i in range(1, 3):
    models.append(keras.models.load_model('mlp_model{}_checkpoint.h5'.format(i)))

# %%
def recursive_predict(model, X_test, n_inputs, n_features, total_timesteps):
    # 只能用每个里面的第一部分，其他用预测来填充
    gap = total_timesteps - n_inputs
    y_pred = []
    i = 0
    while i < len(X_test):
        history = [num for num in X_test[i]]
        i += gap
        inner_pred = []
        for j in range(total_timesteps - n_inputs):
            X = np.array(history[-n_features * n_inputs:]).reshape(1, n_features * n_inputs)
            pred = list(model.predict(X)[0])
            inner_pred.append(pred[-2])
            history += pred
        y_pred.append(np.array(inner_pred))
    return np.array(y_pred)

# %%
y_preds = []
y_tests = []
for i in range(len(models)):
    y_preds.append(recursive_predict(models[i], test_xs[i], 11, 10, 16))
    y_tests.append(test_ys[i][:, -2].reshape(len(test_ys[i]) // 5, -1))
y_pred = np.concatenate(y_preds)
y_test = np.concatenate(y_tests)

# %%
y_test.shape
# Out:
# (529, 5)

# %% [markdown]
# 画图

# %%
# 训练集
ids = random.sample(range(len(y_test)), 10)

plt.figure(figsize=(12,8))
for i in range(10):
    plt.subplot(5,2,i+1)
    plt.plot(np.concatenate((X_train[ids[i], :, -2], y_train[ids[i]].reshape(-1)), axis=None), label='actual', zorder=1)
    plt.plot(np.concatenate((X_train[ids[i], :, -2], y_pred[ids[i]].reshape(-1)), axis=None), label='predict', zorder=0)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# 测试集
ids = random.sample(range(len(y_test)), 10)

plt.figure(figsize=(12,8))
for i in range(10):
    plt.subplot(5,2,i+1)
    plt.plot(np.concatenate((X_test[ids[i], :, -2], y_test[ids[i]].reshape(-1)), axis=None), label='actual', zorder=1)
    plt.plot(np.concatenate((X_test[ids[i], :, -2], y_pred[ids[i]].reshape(-1)), axis=None), label='predict', zorder=0)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 评估

# %%
metrics = ['mae', 'ndcg']

for m in metrics:
    overall, annual = eval_model(m, y_test, y_pred, scaler)
    print('{}:'.format(m.upper()), overall)
    print('{}MAE:'.format(m.upper()),annual)
    plt.plot(annual)
    plt.show()
# Out:
# MAE: 0.7577128850180498
# MAEMAE: [0.40365845 0.58830736 0.81687004 0.91647134 1.06325722]
# NDCG: 0.4556284937314146
# NDCGMAE: [0.04105873575248922, 0.30513656613350737, 0.0005439950162890325, 0.04750151971703334, 0.014322968923956732]
# C:\Users\Tom Leung\OneDrive\文件\武汉大学\硕士投稿\主题热度预测\program\utils.py:36: RuntimeWarning: invalid value encountered in true_divide
#   pred_score = np.sum((2 ** pred_array[:, 1] - 1) / np.log2(pred_array[:, 0] + 1))

# %%
_y_true, _y_pred = eval_model('classification', y_test, y_pred, scaler)

# %%
from sklearn.metrics import classification_report
print(classification_report(_y_true.reshape(-1), _y_pred.reshape(-1)))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.86      0.86      0.86      3600
#          2.0       0.33      0.33      0.33       770
#          3.0       0.33      0.33      0.33       515
#          4.0       0.40      0.40      0.40       260
#
#     accuracy                           0.70      5145
#    macro avg       0.48      0.48      0.48      5145
# weighted avg       0.70      0.70      0.70      5145

# %%
errors = np.abs((y_test - y_pred) / y_test)
annual_mape = np.mean(errors, axis=0)
overall_mape = np.mean(errors, axis=None)
overall_mape
# Out:
# 3.646415186256733
