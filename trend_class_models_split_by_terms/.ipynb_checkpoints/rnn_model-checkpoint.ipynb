# %% [markdown]
# ### 循环神经网络模型模型：Encoder-Decoder with LSTM cell
#
# 先按EmergingScore前N年的线性回归趋势将术语分为正负两组，然后为各组训练单独的模型，将预测结果拼合
#
# 0.734 gene MAE
#
# 0.719 transplant MAE

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from utils import *
import tensorflow.keras as keras
from tensorflow.keras import regularizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import OneHotEncoder

random.seed(42)

# %% [markdown]
# 读取数据

# %%
# (term_num, time_steps, feature_num)

gene_arr_path = r'../output/gene_editing/es_with_decay.array'
transplant_arr_path = r'../output/transplant/es_with_decay.array'

gene_arr = pickle.load(open(gene_arr_path, mode='rb'))
transplant_arr = pickle.load(open(transplant_arr_path, mode='rb'))

print('Shape of the gene_editing array:',gene_arr.shape)
print('Shape of the transplant array:',transplant_arr.shape)
# Out:
# Shape of the gene_editing array: (2643, 17, 10)
# Shape of the transplant array: (5141, 17, 10)

# %% [markdown]
# ### 截断数据
# 因2019年两个数据集的EmergingScore大部分都为0，而2018年及之前的情况要好很多，故抛弃2019年数据

# %%
gene_arr = gene_arr[:, :-1, :]
transplant_arr = transplant_arr[:, :-1, :]

print('Shape of the gene_editing array:',gene_arr.shape)
print('Shape of the transplant array:',transplant_arr.shape)
# Out:
# Shape of the gene_editing array: (2643, 16, 10)
# Shape of the transplant array: (5141, 16, 10)

# %% [markdown]
# ### Extra：按照前N年的Emerging Score的趋势进行区分
#
# 要先划分训练集和测试集，然后才能够和其他模型横评
#
# 共训练两个模型，将其预测结果合并

# %%
def split_data_by_trend(data, targets):
    up_data = []
    down_data = []
    up_target = []
    down_target = []
    
    for i in range(len(data)):
        a, b = np.polyfit(range(len(data[i])), data[i, :, -2].reshape(-1), 1)
        if a > 0:
            up_data.append(data[i])
            up_target.append(targets[i])
        else:
            down_data.append(data[i])
            down_target.append(targets[i])
    return np.array(up_data), np.array(up_target), np.array(down_data), np.array(down_target)

# %%
# scaler, data = scale_data(gene_arr, 'standard')
scaler, data = scale_data(transplant_arr, 'standard')

X_train, X_test, y_train, y_test = split_data(data, n_input=11, ratio=0.2)

X_train1, y_train1, X_train2, y_train2 = split_data_by_trend(X_train, y_train)
X_test1, y_test1, X_test2, y_test2 = split_data_by_trend(X_test, y_test)

print('X_trains shape：', X_train1.shape, X_train2.shape)
print('Y_trains shape：', y_train1.shape, y_train2.shape)
print()
print('X_tests shape：', X_test1.shape, X_test2.shape)
print('Y_tests shape：', y_test1.shape, y_test2.shape)
# Out:
# X_trains shape： (990, 11, 10) (1124, 11, 10)
# Y_trains shape： (990, 5) (1124, 5)
#
# X_tests shape： (254, 11, 10) (275, 11, 10)
# Y_tests shape： (254, 5) (275, 5)

# %% [markdown]
# ### 检查各组内的特征相似性

# %%
plot_datax, plot_datay = X_train1, y_train1
ids = random.sample(range(len(plot_datax)), 10)

plt.figure(figsize=(12,8))
for i in range(8):
    plt.subplot(4,2,i+1)
    plt.plot(np.arange(16), np.concatenate((plot_datax[ids[i], :, -2], plot_datay[ids[i]])))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 构建模型

# %%
def build_encoder_decoder_model(lstm_units, dense_units, lr):
    model = keras.models.Sequential()
    model.add(LSTM(lstm_units, activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
    model.add(LSTM(lstm_units, activation='tanh'))
    model.add(RepeatVector(y_train.shape[1]))
    model.add(LSTM(lstm_units, activation='tanh', return_sequences=True))
    model.add(LSTM(lstm_units, activation='tanh', return_sequences=True))
    model.add(TimeDistributed(Dense(dense_units, activation='relu')))
    model.add(TimeDistributed(Dense(1)))
    
    optimizer=keras.optimizers.RMSprop(learning_rate=lr)
    model.compile(loss='mae', optimizer=optimizer)
    return model

# %% [markdown]
# 训练

# %%
train_xs = [X_train1, X_train2]
train_ys = [y_train1, y_train2]
test_xs = [X_test1, X_test2]
test_ys = [y_test1, y_test2]
i_s = [1, 2]

# %%
for train_x, train_y, test_x, test_y, i in zip(train_xs, train_ys, test_xs, test_ys, i_s):
    model = build_encoder_decoder_model(256, 256, 0.0001)
    history = model.fit(train_x, train_y, epochs=100, batch_size=16, verbose=1, validation_data=(test_x, test_y), 
                   callbacks=[
                       ModelCheckpoint('rnn_model{}_checkpoint.h5'.format(i), save_best_only=True,verbose=1)
                   ])
# Out:
# Train on 990 samples, validate on 254 samples
# Epoch 1/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.9314
# Epoch 00001: val_loss improved from inf to 0.93784, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 17s 17ms/sample - loss: 0.9354 - val_loss: 0.9378
# Epoch 2/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8984
# Epoch 00002: val_loss improved from 0.93784 to 0.93536, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8974 - val_loss: 0.9354
# Epoch 3/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8841
# Epoch 00003: val_loss did not improve from 0.93536
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8819 - val_loss: 0.9369
# Epoch 4/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8716
# Epoch 00004: val_loss improved from 0.93536 to 0.91226, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8684 - val_loss: 0.9123
# Epoch 5/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8616
# Epoch 00005: val_loss improved from 0.91226 to 0.90591, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8594 - val_loss: 0.9059
# Epoch 6/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8558
# Epoch 00006: val_loss improved from 0.90591 to 0.90329, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 6s 6ms/sample - loss: 0.8523 - val_loss: 0.9033
# Epoch 7/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8423
# Epoch 00007: val_loss did not improve from 0.90329
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8450 - val_loss: 0.9034
# Epoch 8/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8440
# Epoch 00008: val_loss improved from 0.90329 to 0.88892, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8394 - val_loss: 0.8889
# Epoch 9/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8377
# Epoch 00009: val_loss improved from 0.88892 to 0.88340, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 6s 6ms/sample - loss: 0.8374 - val_loss: 0.8834
# Epoch 10/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8357
# Epoch 00010: val_loss improved from 0.88340 to 0.88159, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 6s 6ms/sample - loss: 0.8344 - val_loss: 0.8816
# Epoch 11/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8338
# Epoch 00011: val_loss did not improve from 0.88159
# 990/990 [==============================] - 6s 6ms/sample - loss: 0.8306 - val_loss: 0.8832
# Epoch 12/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8317
# Epoch 00012: val_loss did not improve from 0.88159
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8297 - val_loss: 0.8819
# Epoch 13/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8275
# Epoch 00013: val_loss improved from 0.88159 to 0.87366, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8279 - val_loss: 0.8737
# Epoch 14/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8211
# Epoch 00014: val_loss did not improve from 0.87366
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8245 - val_loss: 0.8774
# Epoch 15/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8222
# Epoch 00015: val_loss improved from 0.87366 to 0.87076, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8231 - val_loss: 0.8708
# Epoch 16/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8244
# Epoch 00016: val_loss did not improve from 0.87076
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8228 - val_loss: 0.8722
# Epoch 17/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8200
# Epoch 00017: val_loss did not improve from 0.87076
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8171 - val_loss: 0.8744
# Epoch 18/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8183
# Epoch 00018: val_loss improved from 0.87076 to 0.87037, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8177 - val_loss: 0.8704
# Epoch 19/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8200
# Epoch 00019: val_loss improved from 0.87037 to 0.86879, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8151 - val_loss: 0.8688
# Epoch 20/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8155
# Epoch 00020: val_loss improved from 0.86879 to 0.86637, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8135 - val_loss: 0.8664
# Epoch 21/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8117
# Epoch 00021: val_loss did not improve from 0.86637
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8123 - val_loss: 0.8721
# Epoch 22/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8090
# Epoch 00022: val_loss did not improve from 0.86637
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8112 - val_loss: 0.8816
# Epoch 23/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8118
# Epoch 00023: val_loss did not improve from 0.86637
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8116 - val_loss: 0.8684
# Epoch 24/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8071
# Epoch 00024: val_loss did not improve from 0.86637
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8092 - val_loss: 0.8807
# Epoch 25/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8091
# Epoch 00025: val_loss improved from 0.86637 to 0.86300, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8099 - val_loss: 0.8630
# Epoch 26/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8051
# Epoch 00026: val_loss improved from 0.86300 to 0.86009, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8030 - val_loss: 0.8601
# Epoch 27/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7964
# Epoch 00027: val_loss did not improve from 0.86009
# 990/990 [==============================] - 6s 6ms/sample - loss: 0.8044 - val_loss: 0.8687
# Epoch 28/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8036
# Epoch 00028: val_loss did not improve from 0.86009
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8026 - val_loss: 0.8632
# Epoch 29/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7975
# Epoch 00029: val_loss improved from 0.86009 to 0.85871, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8034 - val_loss: 0.8587
# Epoch 30/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8034
# Epoch 00030: val_loss did not improve from 0.85871
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8042 - val_loss: 0.8594
# Epoch 31/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8038
# Epoch 00031: val_loss did not improve from 0.85871
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8025 - val_loss: 0.8628
# Epoch 32/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8052
# Epoch 00032: val_loss improved from 0.85871 to 0.85809, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8027 - val_loss: 0.8581
# Epoch 33/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8035
# Epoch 00033: val_loss did not improve from 0.85809
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8025 - val_loss: 0.8612
# Epoch 34/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8013
# Epoch 00034: val_loss did not improve from 0.85809
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8013 - val_loss: 0.8583
# Epoch 35/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7982
# Epoch 00035: val_loss did not improve from 0.85809
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8014 - val_loss: 0.8612
# Epoch 36/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8039
# Epoch 00036: val_loss did not improve from 0.85809
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.8014 - val_loss: 0.8641
# Epoch 37/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8006
# Epoch 00037: val_loss improved from 0.85809 to 0.85792, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7999 - val_loss: 0.8579
# Epoch 38/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8001
# Epoch 00038: val_loss did not improve from 0.85792
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7992 - val_loss: 0.8640
# Epoch 39/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7983
# Epoch 00039: val_loss improved from 0.85792 to 0.85790, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7989 - val_loss: 0.8579
# Epoch 40/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7943
# Epoch 00040: val_loss improved from 0.85790 to 0.85779, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7979 - val_loss: 0.8578
# Epoch 41/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7950
# Epoch 00041: val_loss did not improve from 0.85779
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7981 - val_loss: 0.8634
# Epoch 42/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8017
# Epoch 00042: val_loss did not improve from 0.85779
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7999 - val_loss: 0.8641
# Epoch 43/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7950
# Epoch 00043: val_loss did not improve from 0.85779
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7980 - val_loss: 0.8679
# Epoch 44/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8009
# Epoch 00044: val_loss improved from 0.85779 to 0.85624, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7995 - val_loss: 0.8562
# Epoch 45/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7991
# Epoch 00045: val_loss did not improve from 0.85624
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7984 - val_loss: 0.8588
# Epoch 46/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7968
# Epoch 00046: val_loss did not improve from 0.85624
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7974 - val_loss: 0.8744
# Epoch 47/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7977
# Epoch 00047: val_loss did not improve from 0.85624
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7981 - val_loss: 0.8635
# Epoch 48/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7967
# Epoch 00048: val_loss did not improve from 0.85624
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7977 - val_loss: 0.8565
# Epoch 49/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7986
# Epoch 00049: val_loss improved from 0.85624 to 0.85326, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7971 - val_loss: 0.8533
# Epoch 50/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7982
# Epoch 00050: val_loss did not improve from 0.85326
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7980 - val_loss: 0.8583
# Epoch 51/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.8007
# Epoch 00051: val_loss did not improve from 0.85326
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7962 - val_loss: 0.8537
# Epoch 52/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7984
# Epoch 00052: val_loss did not improve from 0.85326
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7964 - val_loss: 0.8568
# Epoch 53/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7956
# Epoch 00053: val_loss did not improve from 0.85326
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7964 - val_loss: 0.8570
# Epoch 54/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7935
# Epoch 00054: val_loss did not improve from 0.85326
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7951 - val_loss: 0.8552
# Epoch 55/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7922
# Epoch 00055: val_loss did not improve from 0.85326
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7954 - val_loss: 0.8537
# Epoch 56/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7934
# Epoch 00056: val_loss did not improve from 0.85326
# 990/990 [==============================] - 6s 6ms/sample - loss: 0.7948 - val_loss: 0.8623
# Epoch 57/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7884
# Epoch 00057: val_loss did not improve from 0.85326
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7952 - val_loss: 0.8681
# Epoch 58/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7967
# Epoch 00058: val_loss improved from 0.85326 to 0.85184, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7943 - val_loss: 0.8518
# Epoch 59/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7881
# Epoch 00059: val_loss did not improve from 0.85184
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7919 - val_loss: 0.8692
# Epoch 60/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7940
# Epoch 00060: val_loss did not improve from 0.85184
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7937 - val_loss: 0.8535
# Epoch 61/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7940
# Epoch 00061: val_loss did not improve from 0.85184
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7921 - val_loss: 0.8549
# Epoch 62/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7917
# Epoch 00062: val_loss did not improve from 0.85184
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7928 - val_loss: 0.8559
# Epoch 63/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7925
# Epoch 00063: val_loss did not improve from 0.85184
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7919 - val_loss: 0.8575
# Epoch 64/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7909
# Epoch 00064: val_loss did not improve from 0.85184
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7913 - val_loss: 0.8530
# Epoch 65/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7969
# Epoch 00065: val_loss improved from 0.85184 to 0.85178, saving model to rnn_model1_checkpoint.h5
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7941 - val_loss: 0.8518
# Epoch 66/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7905
# Epoch 00066: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7914 - val_loss: 0.8535
# Epoch 67/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7955
# Epoch 00067: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7926 - val_loss: 0.8539
# Epoch 68/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7886
# Epoch 00068: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7903 - val_loss: 0.8535
# Epoch 69/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7889
# Epoch 00069: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7902 - val_loss: 0.8540
# Epoch 70/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7892
# Epoch 00070: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7905 - val_loss: 0.8595
# Epoch 71/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7903
# Epoch 00071: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7906 - val_loss: 0.8615
# Epoch 72/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7898
# Epoch 00072: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7884 - val_loss: 0.8557
# Epoch 73/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7881
# Epoch 00073: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7902 - val_loss: 0.8547
# Epoch 74/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7926
# Epoch 00074: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7884 - val_loss: 0.8576
# Epoch 75/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7863
# Epoch 00075: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7888 - val_loss: 0.8530
# Epoch 76/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7878
# Epoch 00076: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7880 - val_loss: 0.8572
# Epoch 77/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7877
# Epoch 00077: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 6ms/sample - loss: 0.7888 - val_loss: 0.8573
# Epoch 78/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7838
# Epoch 00078: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7864 - val_loss: 0.8582
# Epoch 79/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7856
# Epoch 00079: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7867 - val_loss: 0.8551
# Epoch 80/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7833
# Epoch 00080: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7851 - val_loss: 0.8558
# Epoch 81/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7898
# Epoch 00081: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7868 - val_loss: 0.8546
# Epoch 82/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7834
# Epoch 00082: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7856 - val_loss: 0.8524
# Epoch 83/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7835
# Epoch 00083: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7839 - val_loss: 0.8554
# Epoch 84/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7864
# Epoch 00084: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7830 - val_loss: 0.8537
# Epoch 85/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7864
# Epoch 00085: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7843 - val_loss: 0.8562
# Epoch 86/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7840
# Epoch 00086: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7837 - val_loss: 0.8583
# Epoch 87/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7838
# Epoch 00087: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7843 - val_loss: 0.8571
# Epoch 88/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7823
# Epoch 00088: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7834 - val_loss: 0.8569
# Epoch 89/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7839
# Epoch 00089: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7838 - val_loss: 0.8545
# Epoch 90/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7844
# Epoch 00090: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7823 - val_loss: 0.8539
# Epoch 91/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7814
# Epoch 00091: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7831 - val_loss: 0.8591
# Epoch 92/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7782
# Epoch 00092: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7802 - val_loss: 0.8653
# Epoch 93/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7813
# Epoch 00093: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7806 - val_loss: 0.8592
# Epoch 94/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7822
# Epoch 00094: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7798 - val_loss: 0.8573
# Epoch 95/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7833
# Epoch 00095: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7820 - val_loss: 0.8546
# Epoch 96/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7842
# Epoch 00096: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7806 - val_loss: 0.8582
# Epoch 97/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7821
# Epoch 00097: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7818 - val_loss: 0.8558
# Epoch 98/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7804
# Epoch 00098: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7798 - val_loss: 0.8564
# Epoch 99/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7780
# Epoch 00099: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7788 - val_loss: 0.8532
# Epoch 100/100
# 976/990 [============================>.] - ETA: 0s - loss: 0.7755
# Epoch 00100: val_loss did not improve from 0.85178
# 990/990 [==============================] - 5s 5ms/sample - loss: 0.7781 - val_loss: 0.8608
# Train on 1124 samples, validate on 275 samples
# Epoch 1/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.6384
# Epoch 00001: val_loss improved from inf to 0.61562, saving model to rnn_model2_checkpoint.h5
# 1124/1124 [==============================] - 19s 17ms/sample - loss: 0.6382 - val_loss: 0.6156
# Epoch 2/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.6143
# Epoch 00002: val_loss improved from 0.61562 to 0.60993, saving model to rnn_model2_checkpoint.h5
# 1124/1124 [==============================] - 7s 6ms/sample - loss: 0.6140 - val_loss: 0.6099
# Epoch 3/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.6042
# Epoch 00003: val_loss improved from 0.60993 to 0.59048, saving model to rnn_model2_checkpoint.h5
# 1124/1124 [==============================] - 6s 6ms/sample - loss: 0.6040 - val_loss: 0.5905
# Epoch 4/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5910
# Epoch 00004: val_loss improved from 0.59048 to 0.58738, saving model to rnn_model2_checkpoint.h5
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5905 - val_loss: 0.5874
# Epoch 5/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5651- ETA: 0s - loss:
# Epoch 00005: val_loss improved from 0.58738 to 0.54740, saving model to rnn_model2_checkpoint.h5
# 1124/1124 [==============================] - 6s 6ms/sample - loss: 0.5648 - val_loss: 0.5474
# Epoch 6/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5576
# Epoch 00006: val_loss did not improve from 0.54740
# 1124/1124 [==============================] - 6s 6ms/sample - loss: 0.5579 - val_loss: 0.5950
# Epoch 7/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5594
# Epoch 00007: val_loss did not improve from 0.54740
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5592 - val_loss: 0.5514
# Epoch 8/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5574
# Epoch 00008: val_loss did not improve from 0.54740
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5569 - val_loss: 0.5481
# Epoch 9/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5564
# Epoch 00009: val_loss did not improve from 0.54740
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5566 - val_loss: 0.5560
# Epoch 10/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5577
# Epoch 00010: val_loss did not improve from 0.54740
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5571 - val_loss: 0.5533
# Epoch 11/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5555
# Epoch 00011: val_loss improved from 0.54740 to 0.54413, saving model to rnn_model2_checkpoint.h5
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5560 - val_loss: 0.5441
# Epoch 12/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5557
# Epoch 00012: val_loss did not improve from 0.54413
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5559 - val_loss: 0.5445
# Epoch 13/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5530
# Epoch 00013: val_loss did not improve from 0.54413
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5541 - val_loss: 0.5457
# Epoch 14/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5538
# Epoch 00014: val_loss did not improve from 0.54413
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5548 - val_loss: 0.5656
# Epoch 15/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5557
# Epoch 00015: val_loss did not improve from 0.54413
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5554 - val_loss: 0.5442
# Epoch 16/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5523
# Epoch 00016: val_loss did not improve from 0.54413
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5537 - val_loss: 0.5539
# Epoch 17/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5549
# Epoch 00017: val_loss did not improve from 0.54413
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5541 - val_loss: 0.5677
# Epoch 18/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5536
# Epoch 00018: val_loss improved from 0.54413 to 0.54345, saving model to rnn_model2_checkpoint.h5
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5539 - val_loss: 0.5434
# Epoch 19/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5537
# Epoch 00019: val_loss did not improve from 0.54345
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5541 - val_loss: 0.5436
# Epoch 20/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5549
# Epoch 00020: val_loss did not improve from 0.54345
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5541 - val_loss: 0.5560
# Epoch 21/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5539
# Epoch 00021: val_loss did not improve from 0.54345
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5539 - val_loss: 0.5551
# Epoch 22/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5543
# Epoch 00022: val_loss did not improve from 0.54345
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5538 - val_loss: 0.5460
# Epoch 23/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5527
# Epoch 00023: val_loss did not improve from 0.54345
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5526 - val_loss: 0.5675
# Epoch 24/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5541
# Epoch 00024: val_loss improved from 0.54345 to 0.54244, saving model to rnn_model2_checkpoint.h5
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5535 - val_loss: 0.5424
# Epoch 25/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5528
# Epoch 00025: val_loss did not improve from 0.54244
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5537 - val_loss: 0.5427
# Epoch 26/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5543
# Epoch 00026: val_loss did not improve from 0.54244
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5540 - val_loss: 0.5444
# Epoch 27/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5540
# Epoch 00027: val_loss did not improve from 0.54244
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5533 - val_loss: 0.5579
# Epoch 28/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5534
# Epoch 00028: val_loss did not improve from 0.54244
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5532 - val_loss: 0.5475
# Epoch 29/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5531
# Epoch 00029: val_loss did not improve from 0.54244
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5524 - val_loss: 0.5533
# Epoch 30/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5507
# Epoch 00030: val_loss did not improve from 0.54244
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5525 - val_loss: 0.5595
# Epoch 31/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5530
# Epoch 00031: val_loss did not improve from 0.54244
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5531 - val_loss: 0.5474
# Epoch 32/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5527
# Epoch 00032: val_loss did not improve from 0.54244
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5523 - val_loss: 0.5432
# Epoch 33/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5530
# Epoch 00033: val_loss did not improve from 0.54244
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5525 - val_loss: 0.5472
# Epoch 34/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5529
# Epoch 00034: val_loss improved from 0.54244 to 0.54113, saving model to rnn_model2_checkpoint.h5
# 1124/1124 [==============================] - 6s 6ms/sample - loss: 0.5532 - val_loss: 0.5411
# Epoch 35/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5527
# Epoch 00035: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 6ms/sample - loss: 0.5524 - val_loss: 0.5434
# Epoch 36/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5518
# Epoch 00036: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5521 - val_loss: 0.5431
# Epoch 37/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5532
# Epoch 00037: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5525 - val_loss: 0.5439
# Epoch 38/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5521
# Epoch 00038: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5517 - val_loss: 0.5469
# Epoch 39/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5529
# Epoch 00039: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5521 - val_loss: 0.5439
# Epoch 40/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5524
# Epoch 00040: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5519 - val_loss: 0.5422
# Epoch 41/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5509
# Epoch 00041: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5514 - val_loss: 0.5487
# Epoch 42/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5517
# Epoch 00042: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5523 - val_loss: 0.5479
# Epoch 43/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5503
# Epoch 00043: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5514 - val_loss: 0.5457
# Epoch 44/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5527
# Epoch 00044: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5519 - val_loss: 0.5439
# Epoch 45/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5532
# Epoch 00045: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5522 - val_loss: 0.5468
# Epoch 46/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5498
# Epoch 00046: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5518 - val_loss: 0.5549
# Epoch 47/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5515
# Epoch 00047: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5523 - val_loss: 0.5428
# Epoch 48/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5513
# Epoch 00048: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5513 - val_loss: 0.5521
# Epoch 49/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5515
# Epoch 00049: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5518 - val_loss: 0.5481
# Epoch 50/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5512
# Epoch 00050: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5514 - val_loss: 0.5494
# Epoch 51/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5498
# Epoch 00051: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5511 - val_loss: 0.5467
# Epoch 52/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5493
# Epoch 00052: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5500 - val_loss: 0.5473
# Epoch 53/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5507
# Epoch 00053: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5507 - val_loss: 0.5438
# Epoch 54/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5519
# Epoch 00054: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 6ms/sample - loss: 0.5510 - val_loss: 0.5428
# Epoch 55/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5509
# Epoch 00055: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5501 - val_loss: 0.5444
# Epoch 56/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5513
# Epoch 00056: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5506 - val_loss: 0.5439
# Epoch 57/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5511
# Epoch 00057: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5505 - val_loss: 0.5445
# Epoch 58/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5508
# Epoch 00058: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5505 - val_loss: 0.5430
# Epoch 59/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5503
# Epoch 00059: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5500 - val_loss: 0.5495
# Epoch 60/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5499
# Epoch 00060: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5499 - val_loss: 0.5478
# Epoch 61/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5490
# Epoch 00061: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5505 - val_loss: 0.5489
# Epoch 62/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5479- ETA: 1
# Epoch 00062: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 6ms/sample - loss: 0.5496 - val_loss: 0.5460
# Epoch 63/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5496
# Epoch 00063: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5497 - val_loss: 0.5433
# Epoch 64/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5495
# Epoch 00064: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5493 - val_loss: 0.5483
# Epoch 65/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5497
# Epoch 00065: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5493 - val_loss: 0.5418
# Epoch 66/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5505
# Epoch 00066: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5499 - val_loss: 0.5466
# Epoch 67/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5470
# Epoch 00067: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5490 - val_loss: 0.5476
# Epoch 68/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5495
# Epoch 00068: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5497 - val_loss: 0.5490
# Epoch 69/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5470
# Epoch 00069: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5490 - val_loss: 0.5485
# Epoch 70/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5492
# Epoch 00070: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5494 - val_loss: 0.5464
# Epoch 71/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5484
# Epoch 00071: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5495 - val_loss: 0.5457
# Epoch 72/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5494
# Epoch 00072: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5493 - val_loss: 0.5448
# Epoch 73/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5488
# Epoch 00073: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5491 - val_loss: 0.5441
# Epoch 74/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5484
# Epoch 00074: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5489 - val_loss: 0.5421
# Epoch 75/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5490
# Epoch 00075: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5488 - val_loss: 0.5416
# Epoch 76/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5487
# Epoch 00076: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5485 - val_loss: 0.5419
# Epoch 77/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5475
# Epoch 00077: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5477 - val_loss: 0.5459
# Epoch 78/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5476
# Epoch 00078: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5480 - val_loss: 0.5519
# Epoch 79/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5496
# Epoch 00079: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5497 - val_loss: 0.5473
# Epoch 80/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5476
# Epoch 00080: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5476 - val_loss: 0.5483
# Epoch 81/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5488
# Epoch 00081: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5480 - val_loss: 0.5447
# Epoch 82/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5464
# Epoch 00082: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5477 - val_loss: 0.5457
# Epoch 83/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5454
# Epoch 00083: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5477 - val_loss: 0.5575
# Epoch 84/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5491
# Epoch 00084: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5487 - val_loss: 0.5503
# Epoch 85/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5479
# Epoch 00085: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5475 - val_loss: 0.5454
# Epoch 86/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5484
# Epoch 00086: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5478 - val_loss: 0.5448
# Epoch 87/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5485
# Epoch 00087: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5480 - val_loss: 0.5486
# Epoch 88/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5480
# Epoch 00088: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5472 - val_loss: 0.5493
# Epoch 89/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5462
# Epoch 00089: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5468 - val_loss: 0.5453
# Epoch 90/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5487
# Epoch 00090: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5485 - val_loss: 0.5498
# Epoch 91/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5471
# Epoch 00091: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5469 - val_loss: 0.5520
# Epoch 92/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5479
# Epoch 00092: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5476 - val_loss: 0.5468
# Epoch 93/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5466
# Epoch 00093: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5467 - val_loss: 0.5497
# Epoch 94/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5477- ET
# Epoch 00094: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 6ms/sample - loss: 0.5469 - val_loss: 0.5504
# Epoch 95/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5476
# Epoch 00095: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 6ms/sample - loss: 0.5480 - val_loss: 0.5504
# Epoch 96/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5460
# Epoch 00096: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5470 - val_loss: 0.5454
# Epoch 97/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5470
# Epoch 00097: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5467 - val_loss: 0.5491
# Epoch 98/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5468
# Epoch 00098: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5474 - val_loss: 0.5471
# Epoch 99/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5465
# Epoch 00099: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 5ms/sample - loss: 0.5478 - val_loss: 0.5483
# Epoch 100/100
# 1120/1124 [============================>.] - ETA: 0s - loss: 0.5457
# Epoch 00100: val_loss did not improve from 0.54113
# 1124/1124 [==============================] - 6s 6ms/sample - loss: 0.5472 - val_loss: 0.5423

# %% [markdown]
# 预测

# %%
models = []
for i in range(1, 3):
    models.append(keras.models.load_model('trained_models/gene_rnn/rnn_model{}_checkpoint.h5'.format(i)))

# %%
y_preds = []
y_tests = []
for i in range(len(models)):
    y_preds.append(models[i].predict(test_xs[i]).reshape(test_ys[i].shape))
    y_tests.append(test_ys[i])
y_pred = np.concatenate(y_preds)
y_test = np.concatenate(y_tests)

# %%
ids = random.sample(range(len(y_test)), 10)

plt.figure(figsize=(12,8))
for i in range(10):
    plt.subplot(5,2,i+1)
    plt.plot(np.concatenate((scaler.inverse_transform(np.expand_dims(X_test[ids[i], :, -2], axis=0)), scaler.inverse_transform(np.expand_dims(y_test[ids[i]].reshape(-1), axis=0))), axis=None), label='actual', zorder=1)
    plt.plot(np.concatenate((scaler.inverse_transform(np.expand_dims(X_test[ids[i], :, -2], axis=0)), scaler.inverse_transform(np.expand_dims(y_pred[ids[i]].reshape(-1), axis=0))), axis=None), label='predict', zorder=0)
plt.legend()
plt.tight_layout()
plt.show()

# %%
ids = random.sample(range(len(y_test)), 10)

plt.figure(figsize=(12,8))
for i in range(10):
    plt.subplot(5,2,i+1)
    plt.plot(np.concatenate((scaler.inverse_transform(np.expand_dims(X_train[ids[i], :, -2], axis=0)), scaler.inverse_transform(np.expand_dims(y_train[ids[i]].reshape(-1), axis=0))), axis=None), label='actual', zorder=1)
    plt.plot(np.concatenate((scaler.inverse_transform(np.expand_dims(X_train[ids[i], :, -2], axis=0)), scaler.inverse_transform(np.expand_dims(train_pred[ids[i]].reshape(-1), axis=0))), axis=None), label='predict', zorder=0)
plt.legend()
plt.tight_layout()
plt.show()

# %%
metrics = ['mae', 'ndcg','rmse']

for m in metrics:
    overall, annual = eval_model(m, y_test, y_pred.reshape(len(y_test), -1), scaler)
    print('{}:'.format(m.upper()), overall)
    print('{}:'.format(m.upper()),annual)
    plt.plot(annual)
    plt.show()
# Out:
# MAE: 0.7338706923636402
# MAE: [0.3961867  0.59723029 0.75767004 0.87749119 1.04077524]
# NDCG: 0.3367757019807167
# NDCG: [0.306880893649066, 0.3304540792943487, 0.018550091587397233, 0.018986993193034974, 0.013885699877026541]
# RMSE: 1.4281951387612648
# RMSE: [0.99595505 1.05127601 1.53289345 1.58605037 1.79896664]

# %%
_y_true, _y_pred = eval_model('classification', y_test, y_pred, scaler)

# %%
from sklearn.metrics import classification_report
print(classification_report(_y_true.reshape(-1), _y_pred.reshape(-1)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.42      1.00      0.59        27
#          1.0       0.69      0.67      0.68      3248
#          2.0       0.18      0.18      0.18      1059
#          3.0       0.40      0.34      0.37       548
#          4.0       0.21      0.28      0.24       263
#
#     accuracy                           0.52      5145
#    macro avg       0.38      0.50      0.41      5145
# weighted avg       0.53      0.52      0.52      5145
